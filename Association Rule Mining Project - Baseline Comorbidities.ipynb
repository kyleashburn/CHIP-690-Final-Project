# %% [markdown]
# ## Pulling Baseline Comorbidities

# %% [markdown]
# Credit: Dr. Krisnamurthy & Lab 9

# %%
import os
import sqlalchemy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
creds = pd.read_csv("sample_mimic_login_creds.csv")
myUserName = str(creds.iloc[0]['Username']).strip()
myPassword = str(creds.iloc[0]['password']).strip()

server_url = "mimic-db.renci.unc.edu"
database = "mimic"

# Create Connection String
conn_str = f"{myUserName}:{myPassword}@{server_url}/{database}"

# Create Engine
engine = sqlalchemy.create_engine('postgresql://' + conn_str)

# %%
def get_comorbid_data(patient_count_threshold = 50):
    query = \
    f"with condlist as (\
    select c.concept_name, count(distinct co.person_id) as ptct \
    from omop.condition_occurrence co JOIN omop.concept c ON co.condition_concept_id = c.concept_id \
    where concept_name <> 'No matching concept' \
    group by c.concept_name \
    having count(distinct co.person_id) > {patient_count_threshold} \
    ) \
    \
    select distinct co.person_id, list.concept_name \
    from omop.condition_occurrence co JOIN omop.concept c ON co.condition_concept_id = c.concept_id \
    JOIN condlist list ON c.concept_name = list.concept_name"
    
    return pd.read_sql_query(query, engine)

# %%
# %%time
min_patients = 500 # our own adjustment here
comorbidity_data = get_comorbid_data(min_patients)
print(f"The returned date frame for a {min_patients} patient threshold has {len(comorbidity_data)} rows")
comorbidity_data.head(20)
# Out:
# The returned date frame for a 500 patient threshold has 391216 rows
# Wall time: 13.1 s
#     person_id                                       concept_name
# 0   392775850                            Acquired hypothyroidism
# 1   392775850                       Acute posthemorrhagic anemia
# 2   392775850                       Acute renal failure syndrome
# 3   392775850                    Acute subendocardial infarction
# 4   392775850                                             Anemia
# 5   392775850                   Anemia due to chronic blood loss
# 6   392775850                                    Angina pectoris
# 7   392775850                     Anticoagulant adverse reaction
# 8   392775850                                             Asthma
# 9   392775850                                Atrial fibrillation
# 10  392775850  Benign hypertensive renal disease with renal f...
# 11  392775850  Cerebral infarction due to embolism of cerebra...
# 12  392775850                             Chronic kidney disease
# 13  392775850                     Chronic kidney disease stage 3
# 14  392775850                           Congestive heart failure
# 15  392775850         Coronary arteriosclerosis in native artery
# 16  392775850             Diabetes mellitus without complication
# 17  392775850                          Esophageal reflux finding
# 18  392775850  Hemorrhage AND/OR hematoma complicating procedure
# 19  392775850                                     Hyperlipidemia

# %%
print(f"The data frame has {len(comorbidity_data['person_id'].unique())} patients")
print(f"The data frame includes {len(comorbidity_data['concept_name'].unique())} different conditions")
# Out:
# The data frame has 45798 patients
# The data frame includes 230 different conditions

# %% [markdown]
# Looking for conditions that only occur in 500 patients, we can see a difference from the work we did in class.

# %%
new_d = comorbidity_data.groupby(['person_id'])
type(new_d)
print(new_d)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001B99C9CCA90>

# %%
new_d = comorbidity_data.groupby(['person_id'])

comorb_list = []
for person, comorb in new_d:
#     print(f"Person is {person}")
#     print(comorb['concept_name'])
    comorb_list.append(list(set(comorb['concept_name'])))
print(len(comorb_list))
# Out:
# 45798

# %%
comorb_list[::500] # start, stop, step -> but why is there a 5000 step in cycling through the list?
# Out:
# [['Paralytic ileus',
#   'Acute subendocardial infarction',
#   'Chronic kidney disease stage 3',
#   'Respiratory insufficiency',
#   'Low blood pressure',
#   'Anemia due to chronic blood loss',
#   'Benign hypertensive renal disease with renal failure',
#   'Congestive heart failure',
#   'Malnutrition',
#   'Acute renal failure syndrome',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Hyperlipidemia',
#   'Iatrogenic hypotension',
#   'Cerebral infarction due to embolism of cerebral arteries',
#   'Angina pectoris',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetes mellitus without complication',
#   'Acute posthemorrhagic anemia',
#   'Chronic kidney disease',
#   'Old myocardial infarction',
#   'Late effect of medical and surgical care complication',
#   'Acquired hypothyroidism',
#   'Not for resuscitation',
#   'Anemia',
#   'Asthma',
#   'Anticoagulant adverse reaction',
#   'Esophageal reflux finding',
#   'Atrial fibrillation'],
#  ['Accident',
#   'Iatrogenic hypotension',
#   'Paroxysmal ventricular tachycardia',
#   'Coronary arteriosclerosis in native artery',
#   'Acute myocardial infarction of inferior wall',
#   'Abnormal patient reaction',
#   'Cardiac arrhythmia'],
#  ['Chest pain',
#   'Cardiac complication',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Hyperlipidemia',
#   'Coronary arteriosclerosis in native artery',
#   'Disorder of cardiovascular prostheses and implants',
#   'Nonproliferative diabetic retinopathy',
#   'Diabetes mellitus without complication',
#   'Diabetic on insulin',
#   'Abnormal patient reaction',
#   'Asthma',
#   'Urinary tract infectious disease',
#   'Esophageal reflux finding',
#   'Essential hypertension',
#   'Preinfarction syndrome',
#   'Old myocardial infarction',
#   'Pure hypercholesterolemia',
#   'Atrial fibrillation'],
#  ['Newborn',
#   'Gestation period, 33 weeks',
#   'Neonatal jaundice associated with preterm delivery',
#   'Feeding problems in newborn',
#   'Finding related to pregnancy',
#   'Single live birth',
#   'Respiratory distress syndrome in the newborn'],
#  ['Essential hypertension', 'Chronic obstructive lung disease'],
#  ['Dementia associated with another disease',
#   'Anemia due to chronic blood loss',
#   "Alzheimer's disease",
#   'Lower gastrointestinal hemorrhage',
#   'Diaphragmatic hernia'],
#  ['Hemorrhage AND/OR hematoma complicating procedure',
#   'Stroke',
#   'Essential hypertension',
#   'Bacteremia',
#   'Seizure',
#   'Anemia',
#   'Pneumonia due to methicillin susceptible Staphylococcus aureus',
#   'Urinary tract infectious disease',
#   'Cerebral hemorrhage'],
#  ['Tobacco dependence syndrome',
#   'Coronary arteriosclerosis in native artery',
#   'Esophageal reflux finding',
#   'Essential hypertension',
#   'Hypokalemia',
#   'Pure hypercholesterolemia',
#   'Atrial fibrillation'],
#  ['Hemorrhage AND/OR hematoma complicating procedure',
#   'Ascites',
#   'Acute renal failure syndrome',
#   'Hypo-osmolality and or hyponatremia',
#   'Gastrointestinal complication'],
#  ['Acidosis',
#   'Low blood pressure',
#   'Cardiac catheterization',
#   'Essential hypertension',
#   'Severe sepsis',
#   'Angina pectoris',
#   'Congestive heart failure',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetes mellitus without complication',
#   'Aortic valve disorder',
#   'Anemia',
#   'Chronic pulmonary heart disease',
#   'Acute respiratory failure',
#   'Acute renal failure syndrome',
#   'Coronary atherosclerosis',
#   'Preinfarction syndrome',
#   'Pure hypercholesterolemia'],
#  ['Seizure',
#   'Dermatitis due to drug AND/OR medicine taken internally',
#   'Hyperkalemia',
#   'Chronic kidney disease stage 5 due to hypertension'],
#  ['Newborn',
#   'Neonatal jaundice',
#   'Transitory tachypnea of newborn',
#   'Single live birth',
#   'Requires vaccination'],
#  ['Requires vaccination', 'Newborn', 'Single live birth'],
#  ['Diastolic heart failure',
#   'Cardiac catheterization',
#   'Hyperlipidemia',
#   'Coronary arteriosclerosis in native artery',
#   'Aortic valve disorder',
#   'Chronic pulmonary heart disease',
#   'Essential hypertension',
#   'Atrial fibrillation'],
#  ['Requires vaccination', 'Newborn', 'Single live birth', 'Neonatal jaundice'],
#  ['Cerebral infarction due to embolism of cerebral arteries',
#   'Acute subendocardial infarction',
#   'Coronary arteriosclerosis in native artery',
#   'Congestive heart failure',
#   'Severe sepsis',
#   'Pleural effusion',
#   'Infection resistant to penicillin',
#   'Pneumonia',
#   'Urinary tract infectious disease',
#   'Acute renal failure syndrome',
#   'Infection by methicillin sensitive Staphylococcus aureus',
#   'Chronic kidney disease',
#   'Essential hypertension',
#   'High risk drug monitoring status',
#   'Chronic obstructive lung disease'],
#  ['Neonatal bradycardia',
#   'Newborn',
#   'Twins - both live born',
#   'Primary apnea in the newborn',
#   'Neonatal jaundice associated with preterm delivery',
#   'Finding related to pregnancy',
#   'Respiratory distress syndrome in the newborn',
#   'Requires vaccination'],
#  ['Essential hypertension',
#   'Intracranial hemorrhage',
#   'Esophageal reflux finding',
#   'Cerebral hemorrhage',
#   'Pure hypercholesterolemia'],
#  ['Paralytic ileus',
#   'Cardiac complication',
#   'Thrombocytopenic disorder',
#   'Acute subendocardial infarction',
#   'Congestive heart failure',
#   'Acute posthemorrhagic anemia',
#   'Trauma and postoperative pulmonary insufficiency'],
#  ['Neonatal bradycardia',
#   'Newborn',
#   'Primary apnea in the newborn',
#   'Gestation period, 33 weeks',
#   'Neonatal jaundice associated with preterm delivery',
#   'Feeding problems in newborn',
#   'Finding related to pregnancy',
#   'Single live birth',
#   'Respiratory distress syndrome in the newborn'],
#  ['Requires vaccination', 'Newborn', 'Single live birth'],
#  ['Acquired hypothyroidism',
#   'Anemia in chronic kidney disease',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Benign hypertensive renal disease with renal failure',
#   'Acute subendocardial infarction',
#   'Coronary arteriosclerosis in native artery',
#   'Congestive heart failure',
#   'Hypo-osmolality and or hyponatremia',
#   'Diabetes mellitus without complication',
#   'Anemia',
#   'Pneumonia',
#   'Acute renal failure syndrome',
#   'Acute on chronic diastolic heart failure',
#   'Chronic kidney disease',
#   'Preinfarction syndrome',
#   'Gout'],
#  ['Coronary arteriosclerosis in native artery', 'Essential hypertension'],
#  ['Cardiac complication',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetic polyneuropathy',
#   'Asthma',
#   'Essential hypertension',
#   'Preinfarction syndrome',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Atrial fibrillation'],
#  ['Requires vaccination', 'Newborn', 'Single live birth'],
#  ['Acquired hypothyroidism',
#   'Benign hypertensive renal disease with renal failure',
#   'Congestive heart failure',
#   'Cardiac pacemaker in situ',
#   'Mitral valve disorder',
#   'Pneumonia',
#   'Tricuspid valve disorder',
#   'Esophageal reflux finding',
#   'Chronic kidney disease',
#   'Chronic obstructive lung disease',
#   'Atrial fibrillation'],
#  ['Benign hypertensive renal disease with renal failure',
#   'Cerebral infarction due to embolism of cerebral arteries',
#   'Fever',
#   'Urinary tract infectious disease',
#   'Chronic kidney disease',
#   'Late effects of cerebrovascular disease',
#   'Epilepsy',
#   'Pure hypercholesterolemia',
#   'Atrial fibrillation'],
#  ['Hemorrhage AND/OR hematoma complicating procedure',
#   'Peripheral vascular disease',
#   'Gastrointestinal hemorrhage',
#   'Coronary arteriosclerosis in native artery',
#   'Congestive heart failure',
#   'Diabetes mellitus without complication',
#   'Acute posthemorrhagic anemia',
#   'Anemia',
#   'Essential hypertension',
#   'Pure hypercholesterolemia',
#   'Atrial fibrillation'],
#  ['Newborn',
#   'Gestation period, 33 weeks',
#   'Neonatal jaundice associated with preterm delivery',
#   'Finding related to pregnancy',
#   'Single live birth',
#   'Requires vaccination',
#   'Respiratory condition of fetus OR newborn'],
#  ['Angina pectoris', 'Pure hypercholesterolemia', 'Essential hypertension'],
#  ['Pneumonia', 'Chronic pulmonary heart disease', 'Atrial fibrillation'],
#  ['Pneumonitis due to inhalation of food or vomitus',
#   'Hyperosmolality and or hypernatremia',
#   'Seizure',
#   'Toxic encephalopathy',
#   'Glaucoma',
#   'Cardiac pacemaker in situ',
#   'Pleural effusion',
#   'Mitral valve disorder',
#   'Acute renal failure syndrome',
#   'Esophageal reflux finding',
#   'Essential hypertension',
#   'Pure hypercholesterolemia'],
#  ['Newborn',
#   'Neonatal jaundice',
#   'Transitory tachypnea of newborn',
#   'Single live birth',
#   'Requires vaccination'],
#  ['Diastolic heart failure',
#   'Cardiac complication',
#   'Peripheral vascular disease',
#   'Hyperlipidemia',
#   'Hyperkalemia',
#   'Acute subendocardial infarction',
#   'Coronary arteriosclerosis in native artery',
#   'Congestive heart failure',
#   'Malnutrition',
#   'End-stage renal disease',
#   'Cerebrovascular disease',
#   'Chronic systolic heart failure',
#   'Leukocytosis',
#   'Acute respiratory failure',
#   'Chronic kidney disease stage 5 due to hypertension',
#   'Hematochezia',
#   'Old myocardial infarction',
#   'Atrial fibrillation'],
#  ['Acute myocardial infarction',
#   'Cardiac catheterization',
#   'Acute subendocardial infarction',
#   'Coronary arteriosclerosis in native artery',
#   'Cardiogenic shock'],
#  ['Depressive disorder',
#   'Coronary arteriosclerosis in native artery',
#   'Cerebrovascular disease',
#   'Esophageal reflux finding'],
#  ['Twins - both live born',
#   'Newborn',
#   'Neonatal jaundice',
#   'Transitory tachypnea of newborn',
#   'Requires vaccination'],
#  ['Requires vaccination', 'Newborn', 'Single live birth'],
#  ['Sepsis',
#   'Accident',
#   'Severe sepsis',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetes mellitus without complication',
#   'Pneumonia',
#   'Acute renal failure syndrome',
#   'Chronic kidney disease stage 5 due to hypertension',
#   'Organic mental disorder'],
#  ['Paroxysmal ventricular tachycardia', 'Cardiac arrest'],
#  ['Acute posthemorrhagic anemia'],
#  ['Coronary arteriosclerosis',
#   'Hyperlipidemia',
#   'Coronary artery bypass graft',
#   'Angina pectoris',
#   'Coronary arteriosclerosis in native artery',
#   'Essential hypertension'],
#  ['Congestive heart failure',
#   'Clostridium difficile infection',
#   'Vascular complication of medical care',
#   'Acute respiratory failure',
#   'Trauma and postoperative pulmonary insufficiency'],
#  ['Paroxysmal ventricular tachycardia',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Diabetes mellitus without complication',
#   'Acute renal failure syndrome'],
#  ['Alcohol abuse'],
#  ['Sepsis',
#   'Acute exacerbation of chronic obstructive bronchitis',
#   'Abdominal pain',
#   'Diabetes mellitus without complication',
#   'Late effect of medical and surgical care complication',
#   'Gastrointestinal complication',
#   'Chronic obstructive lung disease',
#   'High risk drug monitoring status'],
#  ['Urinary tract infectious disease',
#   'Cirrhosis - non-alcoholic',
#   'Acidosis',
#   'Complication of procedure',
#   'Anemia in chronic kidney disease',
#   'Hepatic encephalopathy',
#   'Blood coagulation disorder',
#   'Anemia of chronic disease',
#   'Malnutrition',
#   'Acute renal failure syndrome',
#   'Alkalosis',
#   'Sepsis',
#   'Thrombocytopenic disorder',
#   'Portal hypertension',
#   'Chronic kidney disease',
#   'Severe sepsis',
#   'Ascites',
#   'Pleural effusion',
#   'Chronic pulmonary heart disease',
#   'Viral hepatitis C',
#   'Infection due to Escherichia coli'],
#  ['Coronary arteriosclerosis',
#   'Cardiac complication',
#   'Hyperlipidemia',
#   'Bacteremia',
#   'Congestive heart failure',
#   'Diabetes mellitus without complication',
#   'Esophageal reflux finding',
#   'Essential hypertension',
#   'Old myocardial infarction',
#   'Atrial fibrillation'],
#  ['Acquired hypothyroidism',
#   'Acute posthemorrhagic anemia',
#   'Esophageal reflux finding',
#   'Essential hypertension',
#   'Pure hypercholesterolemia',
#   'Gout'],
#  ['Pneumonitis due to inhalation of food or vomitus',
#   'Cellulitis and abscess of lower leg',
#   'Dehydration',
#   'Seizure',
#   'Obesity'],
#  ['Complication of procedure',
#   'Atelectasis',
#   'Hyperlipidemia',
#   'Essential hypertension',
#   'Dermatitis due to drug AND/OR medicine taken internally',
#   'Intracranial hemorrhage',
#   'Cerebrovascular disease',
#   'Pleural effusion',
#   'Cerebral infarction due to thrombosis of cerebral arteries',
#   'Vascular complication of medical care',
#   'Hypo-osmolality and or hyponatremia',
#   'Cerebral hemorrhage'],
#  ['Coronary arteriosclerosis',
#   'Cardiac complication',
#   'Acquired hypothyroidism',
#   'Hyperlipidemia',
#   'Disorder of kidney and/or ureter',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetes mellitus without complication',
#   'Tobacco dependence syndrome',
#   'Essential hypertension',
#   'Preinfarction syndrome',
#   'Atrial fibrillation'],
#  ['Coronary arteriosclerosis in native artery', 'Pure hypercholesterolemia'],
#  ['Altered mental status',
#   'High risk drug monitoring status',
#   'Atrial fibrillation'],
#  ['Dysthymia',
#   'Hyperosmolality and or hypernatremia',
#   'Seizure',
#   'Alcoholic cirrhosis',
#   'Disorder of brain',
#   'Esophageal reflux finding'],
#  ['Hypoxemia',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Hypovolemia',
#   'Acute posthemorrhagic anemia',
#   'Asthma',
#   'Depressive disorder',
#   'Esophageal reflux finding',
#   'Essential hypertension',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Late effect of medical and surgical care complication'],
#  ['Hypo-osmolality and or hyponatremia',
#   'Cardiogenic shock',
#   'Urinary tract infectious disease',
#   'Peripheral vascular disease',
#   'Benign hypertensive renal disease with renal failure',
#   'Diabetic - poor control',
#   'Congestive heart failure',
#   'Pneumonia due to methicillin susceptible Staphylococcus aureus',
#   'Acute renal failure syndrome',
#   'High risk drug monitoring status',
#   'Pressure ulcer of lower back',
#   'Sepsis',
#   'Thrombocytopenic disorder',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetes mellitus without complication',
#   'Chronic ischemic heart disease',
#   'Infection resistant to penicillin',
#   'Septic shock',
#   'Chronic kidney disease',
#   'Acute on chronic systolic heart failure',
#   'Old myocardial infarction',
#   'Chronic obstructive lung disease',
#   'Gout',
#   'Pneumonitis due to inhalation of food or vomitus',
#   'Acquired hypothyroidism',
#   'Hepatic necrosis',
#   'Severe sepsis',
#   'Acute exacerbation of chronic obstructive bronchitis',
#   'Acute myocardial infarction of anterior wall',
#   'Anemia',
#   'Mitral valve disorder',
#   'Pneumonia',
#   'Acute respiratory failure',
#   'Esophageal reflux finding',
#   'Essential hypertension',
#   'Hyperkalemia',
#   'Pure hypercholesterolemia',
#   'Atrial fibrillation'],
#  ['Acquired hypothyroidism',
#   'Iron deficiency anemia',
#   'Congestive heart failure',
#   'Aortic valve disorder',
#   'Osteoporosis',
#   'Esophageal reflux finding',
#   'Essential hypertension',
#   'Atrial fibrillation'],
#  ['Sepsis',
#   'Gastrointestinal hemorrhage',
#   'Bacteremia',
#   'Pulmonary embolism with pulmonary infarction',
#   'Congestive heart failure',
#   'Secondary thrombocytopenia',
#   'Acute posthemorrhagic anemia',
#   'Clostridium difficile infection',
#   'Acute disease of cardiovascular system',
#   'Urinary tract infectious disease',
#   'Anticoagulant adverse reaction',
#   'Accidental wound during procedure',
#   'Essential hypertension',
#   'Organic mental disorder',
#   'Diverticular disease of colon',
#   'Gout'],
#  ['Coronary arteriosclerosis',
#   'Hyperlipidemia',
#   'Acute subendocardial infarction',
#   'Coronary arteriosclerosis in native artery',
#   'Tobacco dependence syndrome',
#   'Essential hypertension'],
#  ['Dysthymia',
#   'Dehydration',
#   'Tobacco dependence syndrome',
#   'Hyperosmolality and or hypernatremia',
#   'Seizure',
#   'Chronic hepatitis C',
#   'Alcohol withdrawal syndrome',
#   'Acute renal failure syndrome',
#   'Continuous chronic alcoholism',
#   'Viral hepatitis C',
#   'Essential hypertension',
#   'Esophageal reflux finding',
#   'Diverticular disease of colon'],
#  ['Pressure ulcer of lower back',
#   'Dehydration',
#   'Diabetes mellitus without complication',
#   'Primary malignant neoplasm of respiratory tract',
#   'Anemia',
#   'Pneumonia',
#   'Candidiasis of mouth',
#   'Urinary tract infectious disease',
#   'Acute respiratory failure',
#   'Essential hypertension',
#   'Chronic obstructive lung disease'],
#  ['Chronic hepatitis C',
#   'Cirrhosis - non-alcoholic',
#   'Tobacco dependence syndrome',
#   'Primary malignant neoplasm of respiratory tract',
#   'Epilepsy',
#   'Bipolar disorder',
#   'Acidosis',
#   'Complication of procedure',
#   'Low blood pressure',
#   'Benign hypertensive renal disease with renal failure',
#   'Cerebral edema',
#   'Congestive heart failure',
#   'Pulmonary emphysema',
#   'Acute renal failure syndrome',
#   'Postoperative infection',
#   'Secondary malignant neoplasm of brain and spinal cord',
#   'Hypovolemia',
#   'Diabetes mellitus without complication',
#   'Chronic kidney disease',
#   'Chronic pain',
#   'Chronic obstructive lung disease',
#   'Acquired hypothyroidism',
#   'Cellulitis and abscess of lower leg',
#   'Diabetic on insulin',
#   'Anemia',
#   'Pneumonia',
#   'Acute respiratory failure',
#   'Viral hepatitis C',
#   'Essential hypertension',
#   'Hyperkalemia',
#   'Gout'],
#  ['Acute subendocardial infarction',
#   'Type 2 diabetes mellitus',
#   'Urinary tract infectious disease',
#   'Coronary arteriosclerosis',
#   'Anemia in chronic kidney disease',
#   'Peripheral vascular disease',
#   'Congestive heart failure',
#   'End-stage renal disease',
#   'Acute renal failure syndrome',
#   'High risk drug monitoring status',
#   'Cardiac complication',
#   'Kidney disorder due to diabetes mellitus',
#   'Iatrogenic hypotension',
#   'Nervous system disorder due to diabetes mellitus',
#   'Thrombocytopenic disorder',
#   'Coronary artery bypass graft',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetes mellitus without complication',
#   'Diabetic polyneuropathy',
#   'Chronic ischemic heart disease',
#   'Chronic systolic heart failure',
#   'Leukocytosis',
#   'Chronic kidney disease stage 5 due to hypertension',
#   'Acute on chronic systolic heart failure',
#   'Old myocardial infarction',
#   'Paroxysmal ventricular tachycardia',
#   'Disorder of cardiovascular prostheses and implants',
#   'Cardiac pacemaker in situ',
#   'Cardiac arrhythmia',
#   'Mitral valve disorder',
#   'Clostridium difficile infection',
#   'Acute respiratory failure',
#   'Pure hypercholesterolemia',
#   'Retention of urine',
#   'Atrial fibrillation'],
#  ['Hepatic encephalopathy',
#   'Thrombocytopenic disorder',
#   'Anemia due to chronic blood loss',
#   'Blood coagulation disorder',
#   'Gastrointestinal hemorrhage',
#   'Hyperosmolality and or hypernatremia',
#   'Portal hypertension',
#   'Diabetes mellitus without complication',
#   'Depressive disorder',
#   'Shock',
#   'Cirrhosis - non-alcoholic',
#   'Coronary atherosclerosis'],
#  ['Benign prostatic hypertrophy without outflow obstruction',
#   'Congestive heart failure',
#   'Complete atrioventricular block',
#   'Anemia',
#   'Depressive disorder',
#   'Acute renal failure syndrome',
#   'Essential hypertension'],
#  ['Pneumonitis due to inhalation of food or vomitus',
#   'Hypo-osmolality and or hyponatremia',
#   'Fall',
#   'Tobacco dependence syndrome',
#   'Fall on or from stairs or steps'],
#  ['Pneumonitis due to inhalation of food or vomitus',
#   'Atelectasis',
#   'Diabetes mellitus without complication',
#   'Mixed acid-base balance disorder',
#   'Altered mental status',
#   'Acute respiratory failure',
#   'Disturbance of consciousness',
#   'Essential hypertension',
#   'Bipolar disorder'],
#  ['Pneumonitis due to inhalation of food or vomitus',
#   'Low blood pressure',
#   'Cerebral infarction due to embolism of cerebral arteries',
#   'Seizure',
#   'Cerebrovascular disease',
#   'Acute respiratory failure',
#   'Essential hypertension',
#   'Atrial fibrillation'],
#  ['Hyperlipidemia',
#   'Essential hypertension',
#   'Stroke',
#   'Diabetes mellitus without complication',
#   'Coronary atherosclerosis',
#   'Transient cerebral ischemia',
#   'Cerebral hemorrhage',
#   'Pure hypercholesterolemia'],
#  ['Pneumonitis due to inhalation of food or vomitus',
#   'Pressure ulcer of lower back',
#   'Iatrogenic hypotension',
#   'Cerebral edema',
#   'Secondary malignant neoplasm of lung',
#   'Tachycardia',
#   'Altered mental status',
#   'Hypo-osmolality and or hyponatremia',
#   'Secondary malignant neoplasm of brain and spinal cord',
#   'Chronic pain',
#   'Subarachnoid hemorrhage',
#   'High risk drug monitoring status',
#   'Pure hypercholesterolemia',
#   'Secondary malignant neoplasm of bone'],
#  ['Twins - both live born', 'Newborn', 'Gestation period, 35 weeks'],
#  ['Chest pain',
#   'Dysthymia',
#   'Sepsis',
#   'Severe sepsis',
#   'Obstructive sleep apnea syndrome',
#   'Asthma',
#   'Chronic pulmonary heart disease',
#   'Pneumonia',
#   'Septic shock',
#   'Acute respiratory failure',
#   'Esophageal reflux finding',
#   'Essential hypertension'],
#  ['Dehydration',
#   'Hyperlipidemia',
#   'Altered mental status',
#   'Urinary tract infectious disease',
#   'Acute renal failure syndrome',
#   'Tobacco dependence syndrome',
#   'Essential hypertension'],
#  ['Acquired hypothyroidism',
#   'Thrombocytopenic disorder',
#   'Hyperlipidemia',
#   'Benign hypertensive renal disease with renal failure',
#   'Iatrogenic hypotension',
#   'Congestive heart failure',
#   'Hypo-osmolality and or hyponatremia',
#   'Obesity',
#   'Diabetes mellitus without complication',
#   'Chronic kidney disease stage 3',
#   'Anemia',
#   'Asthma',
#   'Chronic systolic heart failure',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Esophageal reflux finding',
#   'Old myocardial infarction',
#   'Late effect of medical and surgical care complication',
#   'Atrial fibrillation'],
#  ['Ulcer of foot',
#   'Nervous system disorder due to diabetes mellitus',
#   'Diabetic polyneuropathy',
#   'Acute renal failure syndrome',
#   'Viral hepatitis C',
#   'Hyperkalemia'],
#  ['Iron deficiency anemia',
#   'Diabetes mellitus without complication',
#   'Acute posthemorrhagic anemia',
#   'Upper gastrointestinal bleeding',
#   'Osteoporosis',
#   'Essential hypertension',
#   'Diaphragmatic hernia'],
#  ['Stroke',
#   'Cerebral edema',
#   'Essential hypertension',
#   'Diabetes mellitus without complication',
#   'Gout',
#   'Transient cerebral ischemia',
#   'Acute renal failure syndrome',
#   'Cerebral hemorrhage',
#   'Disorder of kidney and/or ureter'],
#  ['Atelectasis',
#   'Hyperlipidemia',
#   'Seizure',
#   'Essential hypertension',
#   'Respiratory insufficiency',
#   'Late effects of cerebrovascular disease',
#   'High risk drug monitoring status',
#   'Atrial fibrillation'],
#  ['Complication of procedure',
#   'Low blood pressure',
#   'Primary cardiomyopathy',
#   'Stroke',
#   'Cerebral infarction due to embolism of cerebral arteries',
#   'Pneumonia',
#   'Transient cerebral ischemia',
#   'Atrial fibrillation'],
#  ['Dysthymia',
#   'Atelectasis',
#   'Hyperosmolality and or hypernatremia',
#   'Coronary arteriosclerosis in native artery',
#   'Not for resuscitation',
#   'Abdominal aortic aneurysm',
#   'Pneumonia',
#   'Organic mental disorder',
#   'Trauma and postoperative pulmonary insufficiency'],
#  ['Pneumonitis due to inhalation of food or vomitus',
#   'Low blood pressure',
#   'Fall on same level from slipping, tripping or stumbling',
#   'Congestive heart failure',
#   'Gout',
#   'Fall',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Essential hypertension',
#   'High risk drug monitoring status',
#   'Atrial fibrillation'],
#  ['Pressure ulcer of lower back',
#   'Complication of procedure',
#   'Atelectasis',
#   'Acquired hypothyroidism',
#   'Cardiac complication',
#   'Hypoxemia',
#   'Low blood pressure',
#   'Sepsis',
#   'Severe sepsis',
#   'Coronary arteriosclerosis in native artery',
#   'Congestive heart failure',
#   'Pleural effusion',
#   'Leukocytosis',
#   'Septic shock',
#   'Postoperative infection',
#   'Essential hypertension',
#   'Late effect of medical and surgical care complication',
#   'Atrial fibrillation'],
#  ['Hyperlipidemia',
#   'Iatrogenic hypotension',
#   'Pleural effusion',
#   'Chronic pulmonary heart disease',
#   'Essential hypertension',
#   'High risk drug monitoring status',
#   'Chronic obstructive lung disease',
#   'Atrial fibrillation'],
#  ['Coronary arteriosclerosis',
#   'Cardiac complication',
#   'Hyperlipidemia',
#   'Coronary artery bypass graft',
#   'Coronary arteriosclerosis in native artery',
#   'Congestive heart failure',
#   'Old myocardial infarction',
#   'Anemia',
#   'Chronic ischemic heart disease',
#   'Chronic systolic heart failure',
#   'Essential hypertension',
#   'Preinfarction syndrome',
#   'High risk drug monitoring status',
#   'Late effect of medical and surgical care complication',
#   'Atrial fibrillation'],
#  ['Chronic kidney disease',
#   'Chronic hepatitis C',
#   'Benign hypertensive renal disease with renal failure'],
#  ['Postoperative infection',
#   'Dysphagia',
#   'Essential hypertension',
#   'Late effects of cerebrovascular disease',
#   'Late effect of medical and surgical care complication'],
#  ['Essential hypertension', 'Fall'],
#  ['Essential hypertension',
#   'Sleep apnea',
#   'Pure hypercholesterolemia',
#   'Disorder of brain'],
#  ['Pneumonia'],
#  ['Cellulitis and abscess of lower leg',
#   'Paroxysmal ventricular tachycardia',
#   'Diarrhea',
#   'Chronic hepatitis C',
#   'Candidiasis of mouth',
#   'Hypokalemia',
#   'Disorder of kidney and/or ureter'],
#  ['Delirium',
#   'Chronic kidney disease stage 3',
#   'Shock',
#   'Urinary tract infectious disease',
#   'Coronary atherosclerosis',
#   'Organic mental disorder',
#   'Acidosis',
#   'Low blood pressure',
#   'Benign hypertensive renal disease with renal failure',
#   'Diabetic - poor control',
#   'Congestive heart failure',
#   'Acute renal failure syndrome',
#   'Sepsis',
#   'Hyperlipidemia',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetes mellitus without complication',
#   'Chronic systolic heart failure',
#   'Septic shock',
#   'Acute on chronic systolic heart failure',
#   'Sepsis due to Streptococcus group D',
#   'Acquired hypothyroidism',
#   'Bacteremia',
#   'Severe sepsis',
#   'Not for resuscitation',
#   'Anemia',
#   'Cardiac arrhythmia',
#   'Hypo-osmolality and or hyponatremia',
#   'Retention of urine']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(comorb_list).transform(comorb_list)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head(25)
# Out:
#     Abdominal aortic aneurysm  Abdominal pain  Abnormal patient reaction  \
# 0                       False           False                      False
# 1                       False           False                      False
# 2                       False           False                      False
# 3                       False           False                      False
# 4                       False           False                      False
# 5                       False           False                      False
# 6                        True            True                      False
# 7                       False           False                      False
# 8                       False           False                      False
# 9                       False           False                      False
# 10                      False           False                      False
# 11                      False           False                      False
# 12                      False           False                      False
# 13                      False           False                      False
# 14                      False           False                      False
# 15                      False           False                      False
# 16                      False           False                      False
# 17                      False           False                      False
# 18                      False           False                      False
# 19                      False           False                      False
# 20                      False           False                      False
# 21                      False           False                      False
# 22                      False            True                      False
# 23                      False           False                      False
# 24                      False           False                      False
#
#     Accident  Accidental wound during procedure  Acidosis  \
# 0      False                              False     False
# 1      False                               True     False
# 2      False                              False     False
# 3      False                              False     False
# 4      False                              False     False
# 5      False                              False     False
# 6      False                              False      True
# 7      False                              False     False
# 8      False                              False     False
# 9      False                              False     False
# 10     False                              False     False
# 11     False                              False     False
# 12     False                              False     False
# 13     False                              False     False
# 14     False                              False     False
# 15     False                              False     False
# 16     False                               True     False
# 17     False                              False     False
# 18     False                              False     False
# 19     False                              False     False
# 20     False                              False     False
# 21     False                              False     False
# 22     False                              False     False
# 23     False                              False     False
# 24     False                              False     False
#
#     Acquired hypothyroidism  Acute deep vein thrombosis of lower limb  \
# 0                      True                                     False
# 1                     False                                     False
# 2                     False                                     False
# 3                     False                                      True
# 4                      True                                     False
# 5                     False                                     False
# 6                     False                                     False
# 7                     False                                     False
# 8                     False                                     False
# 9                     False                                     False
# 10                    False                                     False
# 11                    False                                     False
# 12                    False                                     False
# 13                    False                                     False
# 14                    False                                     False
# 15                    False                                     False
# 16                    False                                     False
# 17                    False                                     False
# 18                    False                                     False
# 19                    False                                     False
# 20                    False                                     False
# 21                    False                                     False
# 22                    False                                     False
# 23                    False                                     False
# 24                    False                                     False
#
#     Acute disease of cardiovascular system  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# 5                                    False
# 6                                    False
# 7                                    False
# 8                                    False
# 9                                    False
# 10                                   False
# 11                                   False
# 12                                   False
# 13                                   False
# 14                                   False
# 15                                   False
# 16                                   False
# 17                                   False
# 18                                   False
# 19                                   False
# 20                                   False
# 21                                   False
# 22                                   False
# 23                                   False
# 24                                   False
#
#     Acute exacerbation of chronic obstructive bronchitis  ...  \
# 0                                               False     ...
# 1                                               False     ...
# 2                                               False     ...
# 3                                               False     ...
# 4                                               False     ...
# 5                                               False     ...
# 6                                               False     ...
# 7                                               False     ...
# 8                                               False     ...
# 9                                               False     ...
# 10                                              False     ...
# 11                                              False     ...
# 12                                              False     ...
# 13                                              False     ...
# 14                                              False     ...
# 15                                              False     ...
# 16                                              False     ...
# 17                                              False     ...
# 18                                              False     ...
# 19                                              False     ...
# 20                                              False     ...
# 21                                              False     ...
# 22                                              False     ...
# 23                                              False     ...
# 24                                              False     ...
#
#     Tricuspid valve disorder  Twins - both live born  \
# 0                      False                   False
# 1                      False                   False
# 2                      False                   False
# 3                      False                   False
# 4                      False                   False
# 5                      False                   False
# 6                      False                   False
# 7                      False                   False
# 8                      False                   False
# 9                      False                   False
# 10                     False                   False
# 11                     False                   False
# 12                     False                   False
# 13                     False                   False
# 14                     False                   False
# 15                     False                   False
# 16                     False                   False
# 17                     False                   False
# 18                     False                   False
# 19                     False                   False
# 20                     False                   False
# 21                     False                   False
# 22                     False                   False
# 23                     False                   False
# 24                     False                   False
#
#     Type 2 diabetes mellitus  Ulcer of foot  Upper gastrointestinal bleeding  \
# 0                      False          False                            False
# 1                      False          False                            False
# 2                      False          False                            False
# 3                      False          False                            False
# 4                      False          False                            False
# 5                      False          False                            False
# 6                      False          False                            False
# 7                      False          False                            False
# 8                      False          False                            False
# 9                      False          False                            False
# 10                     False          False                            False
# 11                     False          False                            False
# 12                     False          False                            False
# 13                     False          False                            False
# 14                     False          False                            False
# 15                     False          False                            False
# 16                     False          False                            False
# 17                     False          False                            False
# 18                     False          False                            False
# 19                     False          False                            False
# 20                     False          False                            False
# 21                     False          False                            False
# 22                     False          False                            False
# 23                     False          False                            False
# 24                     False          False                            False
#
#     Urinary tract infectious disease  Vascular complication of medical care  \
# 0                              False                                  False
# 1                              False                                  False
# 2                              False                                  False
# 3                               True                                  False
# 4                              False                                  False
# 5                              False                                  False
# 6                               True                                  False
# 7                              False                                  False
# 8                              False                                  False
# 9                              False                                  False
# 10                             False                                  False
# 11                             False                                  False
# 12                             False                                  False
# 13                             False                                  False
# 14                             False                                  False
# 15                             False                                  False
# 16                              True                                  False
# 17                             False                                  False
# 18                             False                                  False
# 19                             False                                  False
# 20                             False                                  False
# 21                             False                                  False
# 22                             False                                  False
# 23                             False                                  False
# 24                             False                                  False
#
#     Ventilator associated pneumonia  Ventricular fibrillation  \
# 0                             False                     False
# 1                             False                     False
# 2                             False                     False
# 3                             False                     False
# 4                             False                     False
# 5                             False                     False
# 6                             False                     False
# 7                             False                     False
# 8                             False                     False
# 9                             False                     False
# 10                            False                     False
# 11                            False                     False
# 12                            False                     False
# 13                            False                     False
# 14                            False                     False
# 15                            False                     False
# 16                            False                     False
# 17                            False                     False
# 18                            False                     False
# 19                            False                     False
# 20                            False                     False
# 21                            False                     False
# 22                            False                      True
# 23                            False                     False
# 24                            False                     False
#
#     Viral hepatitis C
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8               False
# 9               False
# 10              False
# 11              False
# 12              False
# 13              False
# 14              False
# 15              False
# 16              False
# 17              False
# 18              False
# 19              False
# 20              False
# 21              False
# 22              False
# 23              False
# 24              False
#
# [25 rows x 230 columns]

# %%
# %%time
from mlxtend.frequent_patterns import apriori
support = 0.01
frequent_itemsets = apriori(df, min_support=support, use_colnames=True)
print(f"Using a support of {support}, found {len(frequent_itemsets)} frequent itemsets")
frequent_itemsets.head(25)
# Out:
# Using a support of 0.01, found 2114 frequent itemsets
# Wall time: 4min 42s
#      support                                           itemsets
# 0   0.013887                        (Abdominal aortic aneurysm)
# 1   0.015590                                   (Abdominal pain)
# 2   0.012752                        (Abnormal patient reaction)
# 3   0.040941                                         (Accident)
# 4   0.020045                (Accidental wound during procedure)
# 5   0.091227                                         (Acidosis)
# 6   0.083737                          (Acquired hypothyroidism)
# 7   0.011332         (Acute deep vein thrombosis of lower limb)
# 8   0.012599           (Acute disease of cardiovascular system)
# 9   0.020590  (Acute exacerbation of chronic obstructive bro...
# 10  0.016551                      (Acute myocardial infarction)
# 11  0.012315     (Acute myocardial infarction of anterior wall)
# 12  0.012883     (Acute myocardial infarction of inferior wall)
# 13  0.022228         (Acute on chronic diastolic heart failure)
# 14  0.021245          (Acute on chronic systolic heart failure)
# 15  0.019761                               (Acute pancreatitis)
# 16  0.092602                     (Acute posthemorrhagic anemia)
# 17  0.208262                     (Acute renal failure syndrome)
# 18  0.146709                        (Acute respiratory failure)
# 19  0.067470                  (Acute subendocardial infarction)
# 20  0.012883             (Acute-on-chronic respiratory failure)
# 21  0.031792                                    (Alcohol abuse)
# 22  0.012402                               (Alcohol dependence)
# 23  0.015306                      (Alcohol withdrawal syndrome)
# 24  0.019608                              (Alcoholic cirrhosis)

# %%
frequent_itemsets['count'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets.head(25)
# Out:
#      support                                           itemsets  count
# 0   0.013887                        (Abdominal aortic aneurysm)      1
# 1   0.015590                                   (Abdominal pain)      1
# 2   0.012752                        (Abnormal patient reaction)      1
# 3   0.040941                                         (Accident)      1
# 4   0.020045                (Accidental wound during procedure)      1
# 5   0.091227                                         (Acidosis)      1
# 6   0.083737                          (Acquired hypothyroidism)      1
# 7   0.011332         (Acute deep vein thrombosis of lower limb)      1
# 8   0.012599           (Acute disease of cardiovascular system)      1
# 9   0.020590  (Acute exacerbation of chronic obstructive bro...      1
# 10  0.016551                      (Acute myocardial infarction)      1
# 11  0.012315     (Acute myocardial infarction of anterior wall)      1
# 12  0.012883     (Acute myocardial infarction of inferior wall)      1
# 13  0.022228         (Acute on chronic diastolic heart failure)      1
# 14  0.021245          (Acute on chronic systolic heart failure)      1
# 15  0.019761                               (Acute pancreatitis)      1
# 16  0.092602                     (Acute posthemorrhagic anemia)      1
# 17  0.208262                     (Acute renal failure syndrome)      1
# 18  0.146709                        (Acute respiratory failure)      1
# 19  0.067470                  (Acute subendocardial infarction)      1
# 20  0.012883             (Acute-on-chronic respiratory failure)      1
# 21  0.031792                                    (Alcohol abuse)      1
# 22  0.012402                               (Alcohol dependence)      1
# 23  0.015306                      (Alcohol withdrawal syndrome)      1
# 24  0.019608                              (Alcoholic cirrhosis)      1

# %%
fi = frequent_itemsets.sort_values(by = ['support'], ascending = False)
print(f"Highest support is {fi.iloc[0]['support']} with a count of {fi.iloc[0]['count']}")
print(f"Lowest support is {fi.iloc[-1]['support']} with a count of {fi.iloc[-1]['count']}")
fi.head(25)
# Out:
# Highest support is 0.3845801126686755 with a count of 1
# Lowest support is 0.01000043670029259 with a count of 3
#        support                                           itemsets  count
# 109   0.384580                           (Essential hypertension)      1
# 83    0.235272       (Coronary arteriosclerosis in native artery)      1
# 40    0.224377                              (Atrial fibrillation)      1
# 79    0.216538                         (Congestive heart failure)      1
# 17    0.208262                     (Acute renal failure syndrome)      1
# 160   0.170772                                          (Newborn)      1
# 130   0.162998                                   (Hyperlipidemia)      1
# 91    0.160924           (Diabetes mellitus without complication)      1
# 18    0.146709                        (Acute respiratory failure)      1
# 777   0.144024  (Coronary arteriosclerosis in native artery, E...      2
# 208   0.139242                                (Single live birth)      1
# 1030  0.138281                       (Newborn, Single live birth)      2
# 225   0.127757                 (Urinary tract infectious disease)      1
# 190   0.126971                             (Requires vaccination)      1
# 1027  0.125857                    (Requires vaccination, Newborn)      2
# 560   0.117887      (Essential hypertension, Atrial fibrillation)      2
# 189   0.116490                        (Pure hypercholesterolemia)      1
# 108   0.115114                        (Esophageal reflux finding)      1
# 28    0.112712                                           (Anemia)      1
# 176   0.112341                                        (Pneumonia)      1
# 1059  0.108913          (Requires vaccination, Single live birth)      2
# 1827  0.108848  (Requires vaccination, Newborn, Single live bi...      3
# 879   0.107537           (Essential hypertension, Hyperlipidemia)      2
# 551   0.102690    (Congestive heart failure, Atrial fibrillation)      2
# 823   0.100070  (Essential hypertension, Diabetes mellitus wit...      2

# %%
fige2 = fi[fi['count'] >= 2]
fige2.head(25)
# Out:
#        support                                           itemsets  count
# 777   0.144024  (Coronary arteriosclerosis in native artery, E...      2
# 1030  0.138281                       (Newborn, Single live birth)      2
# 1027  0.125857                    (Requires vaccination, Newborn)      2
# 560   0.117887      (Essential hypertension, Atrial fibrillation)      2
# 1059  0.108913          (Requires vaccination, Single live birth)      2
# 1827  0.108848  (Requires vaccination, Newborn, Single live bi...      3
# 879   0.107537           (Essential hypertension, Hyperlipidemia)      2
# 551   0.102690    (Congestive heart failure, Atrial fibrillation)      2
# 823   0.100070  (Essential hypertension, Diabetes mellitus wit...      2
# 723   0.099546  (Essential hypertension, Congestive heart fail...      2
# 354   0.093738  (Congestive heart failure, Acute renal failure...      2
# 712   0.091249  (Coronary arteriosclerosis in native artery, C...      2
# 553   0.088650  (Coronary arteriosclerosis in native artery, A...      2
# 367   0.088257  (Essential hypertension, Acute renal failure s...      2
# 911   0.081685  (Essential hypertension, Pure hypercholesterol...      2
# 783   0.080047  (Coronary arteriosclerosis in native artery, H...      2
# 336   0.074567  (Acute renal failure syndrome, Atrial fibrilla...      2
# 326   0.071968  (Acute respiratory failure, Acute renal failur...      2
# 772   0.069108  (Coronary arteriosclerosis in native artery, D...      2
# 934   0.066815            (Finding related to pregnancy, Newborn)      2
# 859   0.064981  (Essential hypertension, Esophageal reflux fin...      2
# 921   0.063758  (Essential hypertension, Urinary tract infecti...      2
# 430   0.062819  (Essential hypertension, Acute respiratory fai...      2
# 424   0.060505  (Congestive heart failure, Acute respiratory f...      2
# 717   0.060374  (Congestive heart failure, Diabetes mellitus w...      2
