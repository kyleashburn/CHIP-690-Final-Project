# %% [markdown]
# ## Pulling comorbidities for Colorectal Cancer Patients

# %% [markdown]
# Credit: Dr. Krisnamurthy & Lab 9

# %%
import os
import sqlalchemy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
creds = pd.read_csv("sample_mimic_login_creds.csv")
myUserName = str(creds.iloc[0]['Username']).strip()
myPassword = str(creds.iloc[0]['password']).strip()

server_url = "mimic-db.renci.unc.edu"
database = "mimic"

# Create Connection String
conn_str = f"{myUserName}:{myPassword}@{server_url}/{database}"

# Create Engine
engine = sqlalchemy.create_engine('postgresql://' + conn_str)

# %% [markdown]
# We aren't trying to restrict by number of patients here because of the realities of our sample size.

# %%
query = """
    -- First step
-- Pulls all the concept ids we need to care about
WITH icd10_conc AS (
SELECT * 
FROM omop.concept
WHERE concept_code LIKE 'C17.%' OR concept_code LIKE 'C18.%' OR
concept_code LIKE 'C21.%' OR  concept_code = 'Z86.010'
),

-- Second step 
-- Pulling the concepts
-- We want to pull the concept_id_2 for each of these
conc_maps AS (
SELECT concept_id_2
FROM omop.concept_relationship 
WHERE concept_id_1 in (SELECT concept_id FROM icd10_conc) 
AND relationship_id = 'Maps to'
)
,

-- third step -> ensuring all standard concepts
-- ensuring these are all standard concepts
stand_conc as (
SELECT concept_id_2 as cond_conc_id
FROM conc_maps cm
INNER JOIN omop.concept co ON cm.concept_id_2 = co.concept_id
WHERE co.standard_concept = 'S'
),


-- checking to see if they are in the condition occurrence table
canc_pats as (
SELECT DISTINCT co.person_id, co.condition_concept_id, co.condition_source_value
FROM omop.condition_occurrence co
WHERE co.condition_concept_id IN (SELECT * FROM stand_conc)
),

-- checking to see how many deaths we have records for
canc_deaths as (
SELECT * 
FROM omop.death od
WHERE od.person_id IN (SELECT person_id from canc_pats)
),

-- pulling max & min dates for patients -> range of records
-- earliest visit start to latest visit end provides us with visit dif
vis_max_min AS (
SELECT vo.person_id, MIN(vo.visit_start_datetime) AS first_vis, 
MAX(vo.visit_end_datetime) AS last_vis
FROM omop.visit_occurrence vo
WHERE vo.person_id IN (SELECT person_id FROM canc_pats)
GROUP BY vo.person_id
),

-- earliest procedure start to latest procedure end
proc_max_min AS (
SELECT po.person_id, MIN(po.procedure_datetime) AS first_proc , 
MAX(po.procedure_datetime) AS last_proc
FROM omop.procedure_occurrence po
WHERE po.person_id IN (SELECT person_id FROM canc_pats)
GROUP BY po.person_id
),

-- earliest drug exposure start to latest drug exposure end
drug_max_min AS (
SELECT de.person_id, MIN(drug_exposure_start_datetime) AS first_drug,
MAX(drug_exposure_end_datetime) AS last_drug
FROM omop.drug_exposure de
WHERE de.person_id IN (SELECT person_id FROM canc_pats)
GROUP BY de.person_id
),

-- earliest measurement to latest measurement
-- slows the running down though :(
meas_max_min AS (
SELECT om.person_id, MIN(om.measurement_datetime) AS first_meas, 
MAX(om.measurement_datetime) AS last_meas
FROM omop.measurement om
WHERE om.person_id IN (SELECT person_id FROM canc_pats)
GROUP BY om.person_id
),

-- no device exposures so we can just ignore that...

-- pulling the first and last datapoint date for each of the patients
num_years as (
SELECT cp.person_id, ((
greatest(last_vis, last_proc, last_drug, last_meas)::date -
least(first_vis, first_proc, first_drug, first_meas)::date)/365.25)
AS num_years
FROM canc_pats cp
INNER JOIN vis_max_min vmm ON cp.person_id = vmm.person_id
INNER JOIN proc_max_min pmm ON cp.person_id = pmm.person_id
INNER JOIN drug_max_min dmm ON cp.person_id = dmm.person_id
INNER JOIN meas_max_min mmm ON cp.person_id = mmm.person_id
),

-- figuring out the start of the dx
dx_date AS (
SELECT person_id, MIN(condition_start_datetime) AS pat_dx_date
FROM omop.condition_occurrence co
WHERE co.person_id IN (SELECT person_id FROM canc_pats) AND
co.condition_concept_id IN (SELECT cond_conc_id FROM stand_conc)
GROUP BY co.person_id
),

-- finding the for our patients after their diagnosis
-- returns list of patients and drugs they've taken
pat_drugs as (
SELECT oc.concept_name, de.drug_concept_id
FROM omop.drug_exposure de
INNER JOIN canc_pats cp ON cp.person_id = de.person_id
INNER JOIN dx_date dd ON dd.person_id = de.person_id
INNER JOIN omop.concept oc ON oc.concept_id = de.drug_concept_id
WHERE de.drug_exposure_start_datetime > dd.pat_dx_date
)

-- trying to find co-morbidities
-- gives us a list of patient ids and concept names for comorbiditis
SELECT distinct(co.person_id), oc.concept_name
FROM omop.condition_occurrence co
INNER JOIN canc_pats cp on co.person_id = cp.person_id 
INNER JOIN omop.concept oc on oc.concept_id = co.condition_concept_id
WHERE co.condition_concept_id not in (SELECT * FROM stand_conc) AND 
concept_name <> 'No matching concept';
    """

# %%
# %%time
# need to run the text through sqlalchemy to clean it up
comorbidity_data = pd.read_sql_query(sqlalchemy.text(query), engine)
print(f"The returned date frame with no mimumum patient threshold has {len(comorbidity_data)} rows")
comorbidity_data.head(20)
# Out:
# The returned date frame with no mimumum patient threshold has 3569 rows
# Wall time: 3.83 s
#     person_id                                       concept_name
# 0   392775850                            Acquired hypothyroidism
# 1   392775850                                   Acute bronchitis
# 2   392775850  Acute combined systolic and diastolic heart fa...
# 3   392775850                       Acute posthemorrhagic anemia
# 4   392775850                       Acute renal failure syndrome
# 5   392775850                    Acute subendocardial infarction
# 6   392775850                       Acute systolic heart failure
# 7   392775850                                             Anemia
# 8   392775850                   Anemia due to chronic blood loss
# 9   392775850                                    Angina pectoris
# 10  392775850                     Anticoagulant adverse reaction
# 11  392775850  Arteriosclerosis of autologous vein coronary a...
# 12  392775850                                             Asthma
# 13  392775850                                Atrial fibrillation
# 14  392775850  Benign hypertensive renal disease with renal f...
# 15  392775850  Cerebral infarction due to embolism of cerebra...
# 16  392775850                             Chronic kidney disease
# 17  392775850                     Chronic kidney disease stage 3
# 18  392775850                           Congestive heart failure
# 19  392775850         Coronary arteriosclerosis in native artery

# %%
print(f"The data frame has {len(comorbidity_data['person_id'].unique())} patients")
print(f"The data frame includes {len(comorbidity_data['concept_name'].unique())} different conditions")
# Out:
# The data frame has 213 patients
# The data frame includes 752 different conditions

# %%
new_d = comorbidity_data.groupby(['person_id'])
type(new_d)
print(new_d)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001F064015340>

# %%
new_d = comorbidity_data.groupby(['person_id'])

comorb_list = []
for person, comorb in new_d:
#     print(f"Person is {person}")
#     print(comorb['concept_name'])
    comorb_list.append(list(set(comorb['concept_name'])))
print(len(comorb_list))
# Out:
# 213

# %%
comorb_list[::] # start, stop, step -> no need for a step here I'd say
# Out:
# [['Benign hypertensive renal disease with renal failure',
#   'Low blood pressure',
#   'Frank hematuria',
#   'Old myocardial infarction',
#   'Asthma',
#   'Hemiplegia',
#   'Acute posthemorrhagic anemia',
#   'Acute systolic heart failure',
#   'Anticoagulant adverse reaction',
#   'Respiratory insufficiency',
#   'Cerebral infarction due to embolism of cerebral arteries',
#   'Esophageal reflux finding',
#   'Wound seroma',
#   'Chronic kidney disease stage 3',
#   'Angina pectoris',
#   'Late effect of medical and surgical care complication',
#   'Acute subendocardial infarction',
#   'Anemia',
#   'Dysarthria',
#   'Feces contents abnormal',
#   'Malnutrition',
#   'Arteriosclerosis of autologous vein coronary artery bypass graft',
#   'Acquired hypothyroidism',
#   'Chronic kidney disease',
#   'Paralytic ileus',
#   'Coronary arteriosclerosis in native artery',
#   'Secondary malignant neoplasm of skin',
#   'Not for resuscitation',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Acute combined systolic and diastolic heart failure',
#   'Iatrogenic hypotension',
#   'Intestinal hemorrhage due to angiodysplasia of intestine',
#   'Hyperlipidemia',
#   'Congestive heart failure',
#   'Diabetes mellitus without complication',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Acute bronchitis',
#   'Anemia due to chronic blood loss'],
#  ['Gastrointestinal hemorrhage',
#   'Cardiac complication',
#   'Atrial fibrillation',
#   'Diverticular disease of colon',
#   'Pneumonia',
#   'Congestive heart failure',
#   'Coronary arteriosclerosis in native artery',
#   'Acute myocardial infarction of inferior wall'],
#  ['Urinary tract infectious disease',
#   'Cardiac complication',
#   'Atrial fibrillation',
#   'Pneumonia',
#   'Pulmonary arterial hypertension',
#   'Primary malignant neoplasm of respiratory tract',
#   'Mitral valve disorder',
#   'Congestive heart failure',
#   'Asthma',
#   'Stricture of artery',
#   'Complete atrioventricular block',
#   'Drug-induced delirium',
#   'Intestinal obstruction',
#   'Coronary arteriosclerosis in native artery',
#   'Acute subendocardial infarction'],
#  ['Mitral valve disorder',
#   'Acute posthemorrhagic anemia',
#   'Secondary malignant neoplasm of liver',
#   'Neoplasm of intra-abdominal lymph nodes'],
#  ['Atrial fibrillation',
#   'Malnutrition',
#   'Post-inflammatory pulmonary fibrosis',
#   'Malignant tumor of colon',
#   'Old myocardial infarction',
#   'Chronic obstructive lung disease',
#   'Asthma',
#   'Congestive heart failure',
#   'Chronic kidney disease',
#   'Diabetes mellitus without complication',
#   'Pleural effusion',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Primary cardiomyopathy',
#   'Hypovolemia',
#   'Pressure ulcer',
#   'Chronic pulmonary heart disease'],
#  ['Gastrointestinal hemorrhage',
#   'Urinary tract infectious disease',
#   'Dementia associated with another disease',
#   'Low blood pressure',
#   "Alzheimer's disease",
#   'Acute myocardial infarction of inferoposterior wall',
#   'Diabetes mellitus without complication',
#   'Anemia due to chronic blood loss'],
#  ['Fall from one level to another',
#   'Closed fracture of acetabulum',
#   'Closed fracture of thoracic vertebra without spinal cord injury',
#   'Fall',
#   'Paralytic ileus',
#   'Injury of kidney without open wound into abdominal cavity',
#   'Closed fracture pubis',
#   'Closed fracture of lower end of radius AND ulna'],
#  ['Essential hypertension',
#   'Pure hypercholesterolemia',
#   'Peritoneal adhesion',
#   'Congestive heart failure',
#   'Atherosclerosis of autologous vein bypass graft of limb',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Diabetes mellitus without complication'],
#  ['Acute renal failure syndrome',
#   'Cardiac arrest',
#   'Acidosis',
#   'Atrial fibrillation',
#   'Open wound of forehead without complication',
#   'Secondary malignant neoplasm of liver',
#   'Acute vascular insufficiency of intestine',
#   'Severe sepsis',
#   'Acute respiratory failure',
#   'Urinary tract infectious disease',
#   'Disorder of soft tissue',
#   'Open wound of lip without complication',
#   'Septic shock',
#   'Fall',
#   'Hypovolemia',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Sepsis'],
#  ['Essential hypertension',
#   'Selective immunoglobulin A deficiency',
#   'Acquired hypothyroidism',
#   'Mitral valve disorder',
#   'Chronic obstructive lung disease',
#   'Primary bacterial peritonitis',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Esophageal reflux finding',
#   'Coronary arteriosclerosis in native artery',
#   'Iron deficiency anemia',
#   "Crohn's disease"],
#  ['Sepsis',
#   'Acute renal failure syndrome',
#   'Acidosis',
#   'Malnutrition',
#   'Secondary malignant neoplasm of liver',
#   'Acute respiratory failure',
#   'Infection by methicillin sensitive Staphylococcus aureus',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Vascular complication of medical care',
#   'Acute posthemorrhagic anemia',
#   'Chronic vascular insufficiency of intestine',
#   'Abdominal pain',
#   'Clostridium difficile infection',
#   'Shock',
#   'Anemia due to chronic blood loss',
#   'Bacteremia'],
#  ['Hematochezia',
#   'Anemia',
#   'Psychotic disorder',
#   'Paranoid schizophrenia',
#   'Intestinal volvulus',
#   'Peritoneal adhesion',
#   "Barrett's esophagus",
#   'Peritoneal adhesions with obstruction',
#   'Small bowel obstruction',
#   'Osteoporosis',
#   'Ascites',
#   'Anemia of chronic disease',
#   'Disease of liver',
#   'Iron deficiency anemia',
#   'Paroxysmal ventricular tachycardia'],
#  ['Acute renal failure syndrome',
#   'Cardiac complication',
#   'Acidosis',
#   'Acute vascular insufficiency of intestine',
#   'Intestinal obstruction',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Shock',
#   'Sepsis',
#   'Paroxysmal ventricular tachycardia'],
#  ['Mechanical complication of device',
#   'Obstruction of bile duct',
#   'Ulcerative colitis',
#   'Malignant neoplastic disease',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Esophageal reflux finding',
#   'Intestinal obstruction',
#   'Secondary malignant neoplastic disease',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Sepsis',
#   'Cholangitis',
#   'Sepsis due to Gram negative bacteria'],
#  ['Atelectasis',
#   'Secondary malignant neoplasm of liver',
#   'Diabetic - poor control',
#   'Hyperkalemia',
#   'Chronic kidney disease',
#   'Secondary malignant neoplasm of bone'],
#  ['Benign hypertensive renal disease with renal failure',
#   'Acidosis',
#   'Low blood pressure',
#   'Acute hemorrhagic gastritis',
#   'Acute disease of cardiovascular system',
#   'Urinary tract infectious disease',
#   'Esophageal reflux finding',
#   'Acute duodenal ulcer with hemorrhage but without obstruction',
#   'Gastrointestinal hemorrhage',
#   'Pulmonary embolism with pulmonary infarction',
#   'Cardiac pacemaker in situ',
#   'Gastroduodenitis',
#   'Chronic kidney disease',
#   'Primary cardiomyopathy',
#   'Coronary arteriosclerosis in native artery',
#   'Palpitations',
#   'High risk drug monitoring status',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Dehydration',
#   'Hypertensive heart disease without congestive heart failure',
#   'Clostridium difficile infection',
#   'Hemorrhage AND/OR hematoma complicating procedure'],
#  ['Hepatic necrosis',
#   'Epidermoid cyst of skin',
#   'Secondary malignant neoplasm of liver',
#   'Acute posthemorrhagic anemia',
#   'Anticoagulant adverse reaction',
#   'Esophagitis',
#   'Intestinal obstruction',
#   'Pressure ulcer',
#   'Pressure ulcer of lower back',
#   'Claudication',
#   'Urinary tract infectious disease',
#   'Alcohol dependence',
#   'Upper gastrointestinal bleeding',
#   'Staphylococcal infectious disease',
#   'Peripheral vascular disease',
#   'Essential hypertension',
#   'Severe sepsis',
#   'Ischemic ulcer',
#   'Acute osteomyelitis of ankle and/or foot',
#   'Ulcer of foot',
#   'Cachexia',
#   'Peripheral gangrene',
#   'Sepsis',
#   'High risk drug monitoring status',
#   'Acute renal failure syndrome',
#   'Acute diastolic heart failure',
#   'Acute duodenal ulcer with hemorrhage AND obstruction',
#   'Pulmonary emphysema',
#   'Hyperlipidemia',
#   'Accidental wound during procedure',
#   'Congestive heart failure',
#   'Septic shock'],
#  ['Gastrointestinal hemorrhage',
#   'Overdose',
#   'Atrial fibrillation',
#   'Feces contents abnormal',
#   'Malnutrition',
#   'Poisoning by psychotropic agent',
#   'Acute vascular insufficiency of intestine',
#   'Poisoning by analgesic drug',
#   'Congestive heart failure',
#   'Bipolar I disorder',
#   'Asthma',
#   'Intussusception of intestine',
#   'Drug-induced delirium',
#   'Hypovolemia',
#   'Poisoning by antidepressant',
#   'Poisoning by opiate AND/OR related narcotic',
#   'Suicidal deliberate poisoning',
#   'Movement disorder'],
#  ['Atelectasis',
#   'Diverticular disease of colon',
#   'Delirium',
#   'Dysphagia',
#   'Complication of urinary catheter',
#   'Pneumonia due to methicillin susceptible Staphylococcus aureus',
#   'Hyperosmolality and or hypernatremia',
#   'Retention of urine',
#   'Pressure ulcer of lower back',
#   'Iron deficiency anemia',
#   'Diarrhea',
#   'Chronic systolic heart failure',
#   'Urinary tract infectious disease',
#   'Respiratory complication',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Septic shock',
#   'Stricture of esophagus',
#   'Upper gastrointestinal bleeding',
#   'Anemia of chronic disease',
#   'Idiopathic thrombocytopenic purpura',
#   'Mechanical complication due to urethral indwelling catheter',
#   'Sepsis due to Gram negative bacteria',
#   'Gastrointestinal hemorrhage',
#   'Cardiac complication',
#   'Severe sepsis',
#   'Nutritional marasmus',
#   'Hydronephrosis',
#   'Organic mental disorder',
#   'Hypocalcemia',
#   'Cholelithiasis without obstruction',
#   'Sepsis due to Escherichia coli',
#   'Coronary arteriosclerosis in native artery',
#   'Atrial flutter',
#   'Sepsis',
#   'Asbestosis',
#   'Hearing loss',
#   'High risk drug monitoring status',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Iatrogenic hypotension',
#   'Iatrogenic pneumothorax',
#   'Infection resistant to penicillin',
#   'Postoperative infection',
#   'Congestive heart failure',
#   'Anemia due to chronic blood loss',
#   'Aortic valve disorder'],
#  ['Sepsis',
#   'Hypervolemia',
#   'Acute renal failure syndrome',
#   'Acidosis',
#   'Alcohol withdrawal delirium',
#   'Malnutrition',
#   'Incisional hernia',
#   'Disorder of artery'],
#  ['Anemia',
#   'Atrial fibrillation',
#   'Dementia associated with another disease',
#   'Renal failure syndrome',
#   "Alzheimer's disease",
#   'Purulent peritonitis',
#   'Adult failure to thrive syndrome',
#   'Abdominal pain',
#   'Perforation of intestine'],
#  ['Atrial fibrillation',
#   'Low blood pressure',
#   'Congestive heart failure',
#   'Malignant neoplastic disease',
#   'Respiratory insufficiency'],
#  ['Essential hypertension',
#   'Congestive rheumatic heart failure',
#   'Atrial fibrillation',
#   'Dehydration',
#   'Benign prostatic hypertrophy without outflow obstruction',
#   'Tricuspid valve disorder',
#   'Mitral and aortic incompetence',
#   'Esophageal reflux finding',
#   'Intestinal obstruction',
#   'Peripheral venous insufficiency',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'High risk drug monitoring status'],
#  ['Thrombocytopenic disorder',
#   'Accidental wound during procedure',
#   'Chronic obstructive lung disease',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Hepatic infarction',
#   'Chronic vascular insufficiency of intestine',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Abdominal pain',
#   'Perforation of intestine'],
#  ['Cardiac complication',
#   'Atrial fibrillation',
#   'Iatrogenic hypotension',
#   'Secondary malignant neoplasm of liver',
#   'Acquired hypothyroidism',
#   'Late effect of medical and surgical care complication'],
#  ['Cholelithiasis AND cholecystitis without obstruction',
#   'Congestive heart failure',
#   'Chronic obstructive lung disease',
#   'Diabetic on insulin',
#   'Esophageal reflux finding',
#   'Ostium secundum type atrial septal defect',
#   'Diabetes mellitus without complication'],
#  ['Diverticular disease of colon',
#   'Dysphagia',
#   'Acute posthemorrhagic anemia',
#   'Disorder of pancreatic internal secretion',
#   'Ostium secundum type atrial septal defect',
#   'Hemorrhage of colon due to diverticulosis',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Muscle pain',
#   'Lower gastrointestinal hemorrhage',
#   'Respiratory insufficiency',
#   'Thrombocytopenic disorder',
#   'Gastrointestinal complication',
#   'Hematuria syndrome',
#   'Acquired hemolytic anemia',
#   'Hypertrophic cardiomyopathy',
#   'Peripheral vascular disease',
#   'Acute subendocardial infarction',
#   'Corticosteroids adverse reaction',
#   'Cellulitis and abscess of trunk',
#   'Essential hypertension',
#   'Gastrointestinal hemorrhage',
#   'Anxiety disorder',
#   'Acute and subacute bacterial endocarditis',
#   'Paralytic ileus',
#   'Coronary arteriosclerosis in native artery',
#   'Streptococcal infectious disease',
#   'Atrial flutter',
#   'Acute renal failure syndrome',
#   'Acute diastolic heart failure',
#   'Atrial fibrillation',
#   'Benign neoplasm of colon',
#   'Chest pain',
#   'Postoperative infection',
#   'Peritoneal adhesion',
#   'Congestive heart failure',
#   'Bacteremia'],
#  ['Essential hypertension',
#   'Cardiac complication',
#   'Atrial fibrillation',
#   'Pure hypercholesterolemia',
#   'Malignant tumor of colon',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Late effect of medical and surgical care complication'],
#  ['Atrial fibrillation',
#   'Gastrointestinal complication',
#   'Iatrogenic hypotension',
#   'Persistent postoperative fistula',
#   'Chronic ischemic heart disease',
#   'Type 1 diabetes mellitus without complication',
#   'Congestive heart failure',
#   'Hypocalcemia',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Closed fracture of thoracic vertebra without spinal cord injury',
#   'Paralytic ileus',
#   'Complication of procedure',
#   'Coronary arteriosclerosis in native artery',
#   'Late effect of medical and surgical care complication',
#   'Paroxysmal ventricular tachycardia'],
#  ['Delirium',
#   'Malignant tumor of colon',
#   'Sepsis due to anaerobic bacteria',
#   'Urinary tract obstruction',
#   'Vascular complication of medical care',
#   'Paralytic ileus',
#   'Diabetes mellitus without complication',
#   'Acute disease of cardiovascular system',
#   'Respiratory insufficiency'],
#  ['Ulcerative colitis',
#   'Nausea and vomiting',
#   'Nausea',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Hepatic failure',
#   'Intestinal obstruction',
#   'Hypovolemia',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Cholangitis',
#   'Complication of transplanted liver',
#   'Portal hypertension',
#   'Late effect of medical and surgical care complication',
#   'Vomiting',
#   'Anemia',
#   'Sepsis due to Streptococcus group D',
#   'Viral hepatitis B without hepatic coma',
#   'Abscess of liver',
#   'Disorder of artery',
#   'Sepsis',
#   'Iatrogenic hypotension',
#   'Accidental wound during procedure',
#   'Cirrhosis - non-alcoholic',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Disorder affecting transplanted structure'],
#  ['Urinary tract infectious disease',
#   'Infection resistant to penicillin',
#   'Secondary malignant neoplasm of liver',
#   'Ventricular fibrillation',
#   'Venous thrombosis',
#   'Seizure',
#   'Staphylococcal infectious disease',
#   'Hypovolemia',
#   'Cellulitis and abscess of forearm',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Secondary malignant neoplasm of skin',
#   'Secondary malignant neoplasm of intra-abdominal organs',
#   'Hypokalemia',
#   'Secondary malignant neoplasm of small intestine',
#   'Cellulitis and abscess of trunk'],
#  ['Essential hypertension',
#   'Acute renal failure syndrome',
#   'Secondary malignant neoplasm of liver',
#   'Low blood pressure',
#   'Neutropenic disorder',
#   'Hyperkalemia',
#   'Congestive heart failure',
#   'Hypo-osmolality and or hyponatremia',
#   'Antineoplastic adverse reaction',
#   'Hypovolemia',
#   'Diabetes mellitus without complication',
#   'Diarrhea',
#   'Aortic valve disorder'],
#  ['Essential hypertension',
#   'Abdominal pain',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Abscess of intestine',
#   'Diabetes mellitus without complication',
#   'Perforation of intestine'],
#  ['Diverticular disease of colon',
#   'Pneumonia',
#   'Neoplasm of intrathoracic lymph nodes',
#   'Hypertensive heart disease with congestive heart failure',
#   'Anticoagulant adverse reaction',
#   'Secondary thrombocytopenia',
#   'Nonproliferative diabetic retinopathy',
#   'Iron deficiency anemia',
#   'Chronic diastolic heart failure',
#   'Acute respiratory failure',
#   'Diabetic on insulin',
#   'Vascular complication of medical care',
#   'Sleep apnea',
#   'Disorder of pharynx',
#   'Chronic pulmonary heart disease',
#   'Morbid obesity',
#   'Essential hypertension',
#   'Obstruction of bile duct',
#   'Severe sepsis',
#   'Gastroparesis syndrome',
#   'Cardiac pacemaker in situ',
#   'Respiratory failure',
#   'Eye disorder due to diabetes mellitus',
#   'Secondary malignant neoplasm of lung',
#   'Sepsis',
#   'Disorder of lung',
#   'Acute renal failure syndrome',
#   'Acute diastolic heart failure',
#   'Atrial fibrillation',
#   'Benign neoplasm of colon',
#   'Cellulitis and abscess of toe',
#   'Hyperlipidemia',
#   'Congestive heart failure',
#   'Diabetes mellitus without complication',
#   'Obstructive sleep apnea syndrome'],
#  ['Atherosclerosis of native arteries of the extremities',
#   'Benign hypertensive renal disease with renal failure',
#   'Diverticular disease of colon',
#   'Asthma',
#   'Iron deficiency anemia',
#   'Preinfarction syndrome',
#   'Acute on chronic combined systolic and diastolic heart failure',
#   'Acute respiratory failure',
#   'Hyperkalemia',
#   'Infection by methicillin sensitive Staphylococcus aureus',
#   'Esophageal reflux finding',
#   'Alcohol abuse',
#   'Megaloblastic anemia due to vitamin B>12< deficiency',
#   'Chronic pulmonary heart disease',
#   'Aneurysm of thoracic aorta',
#   'Acute subendocardial infarction',
#   'Accident',
#   'Essential hypertension',
#   'Arteriosclerosis of autologous vein coronary artery bypass graft',
#   'Acute exacerbation of chronic obstructive bronchitis',
#   'Coronary arteriosclerosis in native artery',
#   'Complication of surgical procedure',
#   'Acute on chronic systolic heart failure',
#   'Obstructed hernia of anterior abdominal wall',
#   'Acute renal failure syndrome',
#   'Infection resistant to penicillin',
#   'Leukocytosis',
#   'Postoperative infection',
#   'Congestive heart failure',
#   'Chronic kidney disease stage 2',
#   'Coronary atherosclerosis',
#   'Diabetes mellitus without complication',
#   'Tobacco dependence syndrome',
#   'Obstructive sleep apnea syndrome',
#   'Aortic valve disorder'],
#  ['High risk drug monitoring status',
#   'Atrial fibrillation',
#   'Congestive heart failure',
#   'Acute posthemorrhagic anemia',
#   'Intestinal obstruction',
#   'ECG: atrial fibrillation',
#   'Aortic valve disorder'],
#  ['Essential hypertension',
#   'Gastrointestinal hemorrhage',
#   'Anemia',
#   'Atrial fibrillation',
#   'Low blood pressure',
#   'Acquired coagulation factor deficiency',
#   'Primary malignant neoplasm of middle third of esophagus',
#   'Mitral valve disorder',
#   'Tricuspid valve disorder',
#   'Anticoagulant adverse reaction',
#   'Diabetes mellitus without complication'],
#  ['Atelectasis',
#   'Congestive rheumatic heart failure',
#   'Diverticular disease of colon',
#   'Chronic obstructive lung disease',
#   'Hypovolemia',
#   'Iron deficiency anemia',
#   'Diverticulitis of colon',
#   'Mitral insufficiency and aortic stenosis',
#   'Dysthymia',
#   'Hypervolemia',
#   'Respiratory complication',
#   'Urinary tract infectious disease',
#   'Depressive disorder',
#   'Acute respiratory failure',
#   'Congenital insufficiency of aortic valve',
#   'Antineoplastic adverse reaction',
#   'Esophageal reflux finding',
#   'Wound seroma',
#   'Chronic pulmonary heart disease',
#   'Essential hypertension',
#   'Acquired hypothyroidism',
#   'Labyrinthitis',
#   'Right heart failure',
#   'Postmastectomy lymphedema syndrome',
#   'Complication of surgical procedure',
#   'Atrial flutter',
#   'Diaphragmatic hernia',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Pure hypercholesterolemia',
#   'Chronic passive congestion of liver',
#   'Hyperlipidemia',
#   'Diverticulitis',
#   'Abscess of intestine',
#   'Diabetes mellitus without complication'],
#  ['Acidosis',
#   'Incontinence of feces',
#   'Low blood pressure',
#   'Stenosis of rectum and anus',
#   'Intestinal obstruction',
#   'Hyperkalemia',
#   'Hydroureter',
#   'Esophageal reflux finding',
#   'Secondary malignant neoplastic disease',
#   'Pyelonephritis',
#   'Bacterial infection due to Pseudomonas',
#   'Essential hypertension',
#   'Severe sepsis',
#   'Hydronephrosis',
#   'Coronary arteriosclerosis in native artery',
#   'Acute renal failure syndrome',
#   'Sepsis due to Pseudomonas',
#   'Stoma malfunction',
#   'Septic shock'],
#  ['Essential hypertension',
#   'Gastrointestinal hemorrhage',
#   'Anemia',
#   'Obstruction of bile duct',
#   'Cholelithiasis AND cholecystitis without obstruction',
#   'Secondary malignant neoplasm of liver',
#   'Acquired hypothyroidism',
#   'Complication of internal prosthetic device',
#   'Ostium secundum type atrial septal defect',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Secondary malignant neoplasm of intra-abdominal organs',
#   'Secondary malignant neoplasm of lung',
#   'Cholangitis'],
#  ['Essential hypertension',
#   'Acute renal failure syndrome',
#   'Gastrointestinal hemorrhage',
#   'Atrial fibrillation',
#   'Hematochezia',
#   "Crohn's disease of large bowel",
#   'Rheumatoid arthritis',
#   'Primary cardiomyopathy',
#   'Hypovolemia',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   "Crohn's disease"],
#  ['Pneumonia',
#   'Hyperosmolality and or hypernatremia',
#   'Chronic obstructive lung disease',
#   'Human immunodeficiency virus infection',
#   'Hypovolemia',
#   'Pressure ulcer of lower back',
#   'Hypervolemia',
#   'Urinary tract infectious disease',
#   'Gastrointestinal complication',
#   'Hematuria syndrome',
#   'Peritoneal adhesions with obstruction',
#   'Secondary malignant neoplasm of large intestine',
#   'Secondary malignant neoplasm of trunk',
#   'Cachexia',
#   'Paralytic ileus',
#   'Acute renal failure syndrome',
#   'Iatrogenic hypotension',
#   'Accidental wound during procedure',
#   'Cirrhosis - non-alcoholic',
#   'Diabetes mellitus without complication',
#   'Nervous system disorder due to diabetes mellitus'],
#  ['Post-inflammatory pulmonary fibrosis',
#   'Schizoaffective disorder',
#   'Type 1 diabetes mellitus without complication',
#   'Chronic obstructive lung disease',
#   'Congestive heart failure',
#   'Acute exacerbation of chronic obstructive airways disease',
#   'Schizophrenia',
#   'Vascular complication of medical care',
#   'Acute exacerbation of chronic obstructive bronchitis',
#   'Peripheral vascular disease',
#   'Shock',
#   'Bacteremia'],
#  ['Pneumonia due to methicillin susceptible Staphylococcus aureus',
#   'Acquired hypothyroidism',
#   'Acute respiratory failure',
#   'Old myocardial infarction',
#   'Intestinal obstruction',
#   'Osteoporosis',
#   'Coronary arteriosclerosis in native artery',
#   'Abdominal pain',
#   'Neoplasm of intra-abdominal lymph nodes'],
#  ['Foreign body in trachea',
#   'Asthma',
#   'Acute posthemorrhagic anemia',
#   'Intestinal obstruction',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Gastrointestinal complication',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Inhalation or ingestion of foreign body with respiratory obstruction or suffocation',
#   'Obesity',
#   'Essential hypertension',
#   'Pulmonary embolism with pulmonary infarction',
#   'Paralytic ileus',
#   'Perforation of intestine',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Dehydration',
#   'Disorder of peritoneum',
#   'Iatrogenic pneumothorax',
#   'Spinal stenosis',
#   'Accidental wound during procedure',
#   'Mitral and aortic incompetence',
#   'Stoma malfunction'],
#  ['Benign hypertensive renal disease with renal failure',
#   'Acidosis',
#   'Pneumonia',
#   'Disorder of bone and articular cartilage',
#   'Acute on chronic combined systolic and diastolic heart failure',
#   'Type 2 diabetes mellitus',
#   'Cardiac arrhythmia',
#   'Hyperkalemia',
#   'Esophageal reflux finding',
#   'Gastrointestinal hemorrhage',
#   'Anemia',
#   'Acquired hypothyroidism',
#   'Chronic kidney disease',
#   'Peripheral venous insufficiency',
#   'High risk drug monitoring status',
#   'Benign neoplasm of rectum and anal canal',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Pure hypercholesterolemia',
#   'Hyperlipidemia',
#   'Congestive heart failure',
#   'Diabetes mellitus without complication',
#   'Anemia due to chronic blood loss'],
#  ['Essential hypertension',
#   'Urinary tract infectious disease',
#   'Anemia',
#   'Atrial fibrillation',
#   'Malignant tumor of colon',
#   'Complication of urinary catheter',
#   'Peritoneal adhesion',
#   'Esophageal reflux finding',
#   'Incisional hernia',
#   'Paralytic ileus',
#   'Retention of urine',
#   'Diabetes mellitus without complication',
#   'Bacterial infection due to Pseudomonas'],
#  ['Essential hypertension',
#   'Acute renal failure syndrome',
#   'Cardiac arrest',
#   'Atrial fibrillation',
#   'Dehydration',
#   'Delirium',
#   'Sinus node dysfunction',
#   'Fistula of intestine',
#   'Malignant tumor of colon',
#   'Acquired hypothyroidism',
#   'Acute respiratory failure',
#   'Urinary tract infectious disease',
#   'Hyperosmolality and or hypernatremia',
#   'Congestive heart failure',
#   'Vascular complication of medical care',
#   'Secondary malignant neoplasm of small intestine',
#   'Bacteremia'],
#  ['Benign hypertensive renal disease with renal failure',
#   'Mitral valve disorder',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Carpal tunnel syndrome',
#   'Benign prostatic hypertrophy without outflow obstruction',
#   'Acute respiratory failure',
#   'Depressive disorder',
#   'Post-surgical hypoinsulinemia',
#   'Infection by methicillin sensitive Staphylococcus aureus',
#   'Cellulitis and abscess of trunk',
#   'Essential hypertension',
#   'Accident',
#   'Cardiac complication',
#   'Pelvic organ injury without open wound into abdominal cavity',
#   'Insomnia',
#   'Chronic kidney disease',
#   'Disorder of kidney and/or ureter',
#   'Coronary arteriosclerosis in native artery',
#   'Complication of surgical procedure',
#   'Disorder of pancreas',
#   'Gout',
#   'Arthropathy',
#   'Atrial fibrillation',
#   'Postoperative infection',
#   'Pulmonary emphysema',
#   'Hyperlipidemia',
#   'Congestive heart failure',
#   'Coronary atherosclerosis'],
#  ['Chronic systolic heart failure',
#   'Acute renal failure syndrome',
#   'Gastrointestinal hemorrhage',
#   'Atrial fibrillation',
#   'Nephrosclerosis',
#   'Cardiac pacemaker in situ',
#   'Gastroduodenitis',
#   'Peritoneal adhesion',
#   'Low blood pressure reading',
#   'Congestive heart failure',
#   'Chronic kidney disease',
#   'Iron deficiency anemia',
#   'Benign neoplasm of stomach',
#   'Disorder of kidney and/or ureter',
#   'Coronary arteriosclerosis in native artery',
#   'Hypovolemia',
#   'Complication of surgical procedure',
#   'Diaphragmatic hernia'],
#  ['Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Delirium',
#   'Chronic kidney disease stage 5 due to hypertension',
#   'Pure hypercholesterolemia',
#   'Old myocardial infarction',
#   'Congestive heart failure',
#   'Secondary malignant neoplasm of ovary',
#   'Coronary arteriosclerosis in native artery',
#   'Anemia in neoplastic disease',
#   'Sickle cell trait'],
#  ['Essential hypertension',
#   'Gastrointestinal complication',
#   'Pure hypercholesterolemia',
#   'Malignant tumor of colon',
#   'Paralytic ileus',
#   'Coronary arteriosclerosis in native artery',
#   'Angina pectoris',
#   'Paroxysmal ventricular tachycardia',
#   'Sinus node dysfunction'],
#  ['Pulmonary congestion and hypostasis',
#   'Pneumonia',
#   'Deficiency anemias',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Diarrhea',
#   'Acute respiratory failure',
#   'Cardiac arrhythmia',
#   'Profound impairment, one eye',
#   'Chronic pulmonary heart disease',
#   'Acute subendocardial infarction',
#   'Cardiac pacemaker in situ',
#   'Hypo-osmolality and or hyponatremia',
#   'Chronic kidney disease',
#   'Mixed acid-base balance disorder',
#   'Coronary arteriosclerosis in native artery',
#   'Acute renal failure syndrome',
#   'Chest pain',
#   'Disorder of hematopoietic structure',
#   'Iatrogenic hypotension',
#   'Congestive heart failure',
#   'Constipation'],
#  ['Essential hypertension',
#   'Cardiac complication',
#   'Atrial fibrillation',
#   'Iatrogenic hypotension',
#   'Pure hypercholesterolemia',
#   'Acquired hypothyroidism',
#   'Cardiac arrhythmia',
#   'Abnormal weight loss',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Coronary atherosclerosis',
#   'Second degree atrioventricular block',
#   'Ascites',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetes mellitus without complication',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Angina pectoris',
#   'Atrial flutter',
#   'Secondary malignant neoplasm of small intestine'],
#  ['Atelectasis',
#   'Acidosis',
#   'Secondary malignant neoplasm of liver',
#   'Low blood pressure',
#   'Neoplasm of intrathoracic lymph nodes',
#   'Compression of vein',
#   'Disorder of cardiovascular prostheses and implants',
#   'Pneumonitis due to inhalation of food or vomitus',
#   'Ventricular fibrillation',
#   'Cardiac arrhythmia',
#   'Vascular complication of medical care',
#   'Second degree atrioventricular block',
#   'Acute subendocardial infarction',
#   'Hypotensive episode',
#   'Essential hypertension',
#   'Cardiac arrest',
#   'Cardiac complication',
#   'Gastrointestinal hemorrhage',
#   'Primary malignant neoplasm of kidney',
#   'Chronic kidney disease stage 5 due to hypertension',
#   'Arteriosclerosis of autologous vein coronary artery bypass graft',
#   'Pulmonary arterial hypertension',
#   'Lung cancer',
#   'Chronic kidney disease',
#   'Acute myocardial infarction',
#   'Coronary arteriosclerosis in native artery',
#   'Secondary malignant neoplasm of lung',
#   'Pure hypercholesterolemia',
#   'Congestive heart failure',
#   'Pleural effusion',
#   'Diabetes mellitus without complication',
#   'Hemorrhage AND/OR hematoma complicating procedure'],
#  ['Atelectasis',
#   'Disorders of bilirubin excretion',
#   'Primary malignant neoplasm of soft tissues of abdomen',
#   'Intestinal obstruction',
#   'Compression of vein',
#   'Acute disease of cardiovascular system',
#   'Iron deficiency anemia',
#   'Edema',
#   'Post-surgical malabsorption',
#   'Urinary tract infectious disease',
#   'Thrombocytopenic disorder',
#   'Intestinal disaccharidase deficiency',
#   'Acute respiratory failure',
#   'Pressure ulcer stage 2',
#   "Crohn's disease of small AND large intestines",
#   'Pneumonia due to Klebsiella pneumoniae',
#   'Peritoneal adhesions with obstruction',
#   'Vascular complication of medical care',
#   'Embolism and thrombosis of the vena cava',
#   'Failure to thrive',
#   'Anemia of chronic disease',
#   'Lesion of radial nerve',
#   'Hypercoagulability state',
#   'Cardiac arrest',
#   'Pancytopenia',
#   'Fistula of intestine',
#   'Pressure ulcer of buttock',
#   'Hypo-osmolality and or hyponatremia',
#   'Paralytic ileus',
#   'Sepsis',
#   'High risk drug monitoring status',
#   'Perforation of intestine',
#   'Iatrogenic hypotension',
#   "Crohn's disease of small intestine",
#   'Bacterial infection due to Klebsiella pneumoniae',
#   'Peritoneal adhesion',
#   'Accidental wound during procedure',
#   'Purulent peritonitis',
#   'Stoma malfunction',
#   'Pleural effusion',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Complication'],
#  ['Pneumonia',
#   'Pneumonia due to methicillin susceptible Staphylococcus aureus',
#   'Pneumonitis due to inhalation of food or vomitus',
#   'Urinary tract infectious disease',
#   'Acute respiratory failure',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Essential hypertension',
#   'Polymyalgia rheumatica',
#   'Cardiac complication',
#   'Anemia',
#   'Infarct of cerebrum due to iatrogenic cerebrovascular accident',
#   'Giant cell arteritis',
#   'Acquired hypothyroidism',
#   'Respiratory failure',
#   'High risk drug monitoring status',
#   'Atrial fibrillation',
#   'Pneumonia due to Escherichia coli',
#   'Pure hypercholesterolemia',
#   'Congestive heart failure',
#   'Clostridium difficile infection'],
#  ['Gastrointestinal hemorrhage',
#   'Anemia',
#   'Diverticular disease of colon',
#   'Diastolic heart failure',
#   'Chronic obstructive lung disease',
#   'Congenital anomaly of gastrointestinal tract',
#   'Congestive heart failure',
#   'Diabetic on insulin',
#   'Esophageal reflux finding',
#   'Acute myocardial infarction',
#   'Acute exacerbation of chronic obstructive bronchitis',
#   'Disorder of kidney and/or ureter',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetes mellitus without complication',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Rheumatoid arthritis',
#   'Acute subendocardial infarction',
#   'Aortic valve disorder'],
#  ['Persistent postoperative fistula',
#   'Accidental wound during procedure',
#   'Acute and chronic cholecystitis',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Acute posthemorrhagic anemia',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Secondary malignant neoplasm of intra-abdominal organs'],
#  ['Acidosis',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Intestinal obstruction',
#   'Hypovolemia',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Clostridium difficile infection',
#   'Urinary tract infectious disease',
#   'Gastrointestinal complication',
#   'Nephrogenic diabetes insipidus',
#   'Mild intellectual disability',
#   'Subacute dyskinesia due to drug',
#   'Psoriasis',
#   'Obesity',
#   'Essential hypertension',
#   'Acute appendicitis with peritoneal abscess',
#   'Severe sepsis',
#   'Diabetes insipidus',
#   'Schizoaffective disorder',
#   'Acquired hypothyroidism',
#   'Disorder of posterior pituitary',
#   'Chronic kidney disease',
#   'Sepsis',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Poisoning by psychotropic agent',
#   'Adverse effect, due to correct medicinal substance properly administered',
#   'Purulent peritonitis',
#   'Intellectual disability',
#   'Septic shock'],
#  ['Essential hypertension',
#   'Acute renal failure syndrome',
#   'Cardiac arrest',
#   'Atrial fibrillation',
#   'Gastrointestinal complication',
#   'Severe sepsis',
#   'Acute vascular insufficiency of intestine',
#   'Benign prostatic hypertrophy without outflow obstruction',
#   'Acute respiratory failure',
#   'Abdominal aortic aneurysm',
#   'Hematuria syndrome',
#   'Total urinary incontinence',
#   'Purulent peritonitis',
#   'Septic shock',
#   'Diverticulitis of colon',
#   'Sepsis'],
#  ['Acute respiratory failure',
#   'Mixed acid-base balance disorder',
#   'Paralytic ileus'],
#  ['Essential hypertension',
#   'Secondary malignant neoplasm of liver',
#   'Vascular insufficiency of intestine',
#   'Congestive heart failure',
#   'Schizophrenia',
#   'Intestinal obstruction',
#   'Hypovolemia',
#   'Postoperative shock'],
#  ['Atelectasis',
#   'Atrial fibrillation',
#   'Cardiac complication',
#   'Low blood pressure',
#   'Malignant tumor of colon',
#   'Peritoneal adhesion',
#   'Accidental wound during procedure',
#   'Acute posthemorrhagic anemia',
#   'Paralytic ileus',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Pressure ulcer of upper back',
#   'Complication of surgical procedure',
#   'Acute subendocardial infarction'],
#  ['Benign hypertensive renal disease with renal failure',
#   'Atelectasis',
#   'Acidosis',
#   'Mitral valve disorder',
#   'Asthma',
#   'Adverse reaction to antidiabetic drug',
#   'Incisional hernia with obstruction but no gangrene',
#   'Hypoxemia',
#   'Respiratory complication',
#   'Type 2 diabetes mellitus',
#   'Hyperkalemia',
#   'Esophageal reflux finding',
#   'Acute on chronic diastolic heart failure',
#   'Dermatitis due to drug AND/OR medicine taken internally',
#   'Essential hypertension',
#   'Anemia',
#   'Cardiac complication',
#   'Hair and hair follicle diseases',
#   'Abscess of peritoneum',
#   'Candidiasis of mouth',
#   'Infection AND/OR inflammatory reaction due to internal prosthetic device, implant AND/OR graft',
#   'Hypo-osmolality and or hyponatremia',
#   'Chronic kidney disease',
#   'Coronary arteriosclerosis in native artery',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Leukocytosis',
#   'Pure hypercholesterolemia',
#   'Malignant tumor of colon',
#   'Congestive heart failure',
#   'Hyperosmolar coma associated with diabetes mellitus',
#   'Adverse effect, due to correct medicinal substance properly administered',
#   'Diabetes mellitus without complication',
#   'Clostridium difficile infection'],
#  ['Gastrointestinal complication',
#   'Wound dehiscence',
#   'Congestive heart failure',
#   'Chronic obstructive lung disease',
#   'Acute and chronic cholecystitis',
#   'Tobacco dependence syndrome',
#   'Late effect of medical and surgical care complication',
#   'Secondary malignant neoplasm of intra-abdominal organs'],
#  ['Essential hypertension',
#   'Gastrointestinal hemorrhage',
#   'Hematochezia',
#   'Tetraplegia',
#   'Kidney stone',
#   'Pneumonia',
#   'Hydronephrosis',
#   'Chronic respiratory failure',
#   'Urethral stricture',
#   'Chronic pyelonephritis without medullary necrosis',
#   'Amyotrophic lateral sclerosis'],
#  ['Urinary tract infectious disease',
#   'Atelectasis',
#   'Dementia associated with another disease',
#   'Large bowel obstruction',
#   "Alzheimer's disease",
#   'Second degree atrioventricular block',
#   'Intestinal obstruction',
#   'Hypovolemia',
#   'Multiple sclerosis',
#   'Neoplasm of intra-abdominal lymph nodes'],
#  ['Essential hypertension',
#   'Pressure ulcer of lower back',
#   'Severe sepsis',
#   'Atrial fibrillation',
#   'Pneumonia',
#   'Sepsis due to Streptococcus',
#   'Acute respiratory failure',
#   'Cardiac pacemaker in situ',
#   'Hyperkalemia',
#   'Organic mental disorder',
#   'Congestive heart failure',
#   'Acute posthemorrhagic anemia',
#   'Osteoporosis',
#   'Hypovolemia',
#   'Coronary arteriosclerosis in native artery',
#   'Pneumonitis due to inhalation of food or vomitus',
#   'Angina pectoris',
#   'Postoperative shock'],
#  ['Acute renal failure syndrome',
#   'Gout',
#   'Atrial fibrillation',
#   'Chronic obstructive lung disease',
#   'Congestive heart failure',
#   'Acute on chronic diastolic heart failure',
#   'Acute subendocardial infarction',
#   'Anemia due to chronic blood loss'],
#  ['Acidosis',
#   'Atrial fibrillation',
#   'Pneumonia',
#   'Neutropenic disorder',
#   'Pure hypercholesterolemia',
#   'Hypovolemia',
#   'Diabetes mellitus without complication',
#   'Sepsis'],
#  ['Essential hypertension',
#   'Abnormal patient reaction',
#   'Cardiac complication',
#   'Gastrointestinal hemorrhage',
#   'Mitral valve disorder',
#   'Hyperosmolality and or hypernatremia',
#   'Cardiogenic shock',
#   'Congestive heart failure',
#   'Late effects of cerebrovascular disease',
#   'Acute posthemorrhagic anemia',
#   'Dyspnea',
#   'Coronary arteriosclerosis in native artery',
#   'Diabetes mellitus without complication',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Atrial flutter',
#   'Acute myocardial infarction of inferior wall'],
#  ['Chronic cholecystitis',
#   'Anemia',
#   'Chronic kidney disease stage 5 due to hypertension',
#   'Retinal pigment epithelial dystrophy',
#   'Acute respiratory failure',
#   'Cirrhosis - non-alcoholic',
#   'Cerebral palsy',
#   'Haemophilus influenzae pneumonia',
#   'Lymphadenopathy',
#   'Hyperparathyroidism'],
#  ['Acute hemorrhagic gastritis',
#   'Tabes dorsalis',
#   'Disorder of bone and articular cartilage',
#   'Chronic obstructive lung disease',
#   'Acute posthemorrhagic anemia',
#   'Thrombocytopenic disorder',
#   'Chronic osteomyelitis of ankle and/or foot',
#   'Cellulitis and abscess of foot excluding toe',
#   'Arthropathy associated with a neurological disorder',
#   'Essential hypertension',
#   'Severe sepsis',
#   'Ankle ulcer',
#   'Sepsis',
#   'Asbestosis',
#   'Mechanical complication of vascular device',
#   'Atrial fibrillation',
#   'Diastolic heart failure',
#   'Iatrogenic hypotension',
#   'Infection resistant to penicillin',
#   'Diabetic - poor control',
#   'Congestive heart failure',
#   'Diabetes mellitus without complication',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Septic shock',
#   'Nervous system disorder due to diabetes mellitus'],
#  ['Atherosclerosis of native arteries of the extremities',
#   'Benign hypertensive renal disease with renal failure',
#   'Peripheral vascular disorder due to diabetes mellitus',
#   'Old myocardial infarction',
#   'Cardiogenic shock',
#   'Intermittent claudication',
#   'Acute posthemorrhagic anemia',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Anemia in neoplastic disease',
#   'Systolic heart failure',
#   'Kidney disorder due to diabetes mellitus',
#   'Depressive disorder',
#   'True posterior myocardial infarction',
#   'Diabetic on insulin',
#   'Cataract',
#   'Gouty arthropathy',
#   'Angina pectoris',
#   'Psoriasis',
#   'Acute subendocardial infarction',
#   'Anemia',
#   'Arteriosclerosis of autologous vein coronary artery bypass graft',
#   'Chronic kidney disease',
#   'Coronary arteriosclerosis in native artery',
#   'Anemia in chronic kidney disease',
#   'Acute renal failure syndrome',
#   'Chest pain',
#   'Atrial fibrillation',
#   'Gout',
#   'Iatrogenic hypotension',
#   'Kidney disease',
#   'Pure hypercholesterolemia',
#   'Diabetic - poor control',
#   'Accidental wound during procedure',
#   'Congestive heart failure',
#   'Diabetic polyneuropathy',
#   'Diabetes mellitus without complication',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Spinal stenosis of lumbar region',
#   'Nervous system disorder due to diabetes mellitus'],
#  ['Essential hypertension',
#   'Diverticular disease of colon',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Tobacco dependence syndrome',
#   'Secondary malignant neoplasm of small intestine',
#   'Perforation of intestine'],
#  ['Pneumonia',
#   'Mitral valve disorder',
#   'Secondary thrombocytopenia',
#   'Urinary tract infectious disease',
#   'Benign neoplasm of pancreas, excluding islets of Langerhans',
#   'Opioid analgesic adverse reaction',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Hypertrophic cardiomyopathy',
#   'Esophageal reflux finding',
#   'Chronic pulmonary heart disease',
#   'Chronic kidney disease stage 3',
#   'Late effect of medical and surgical care complication',
#   'Essential hypertension',
#   'Severe sepsis',
#   'Chronic kidney disease stage 5 due to hypertension',
#   'Pulmonary arterial hypertension',
#   'Organic mental disorder',
#   'Tricuspid valve disorder',
#   'Primary cardiomyopathy',
#   'Coronary arteriosclerosis in native artery',
#   'Sepsis',
#   'Acute renal failure syndrome',
#   'Disturbance of consciousness',
#   'Diastolic heart failure',
#   'Pure hypercholesterolemia',
#   'Hyperlipidemia',
#   'Congestive heart failure',
#   'Amnesia',
#   'Diabetes mellitus without complication'],
#  ['Atelectasis',
#   'Old myocardial infarction',
#   'Chronic obstructive lung disease',
#   'Pneumonitis due to inhalation of food or vomitus',
#   'Iron deficiency anemia',
#   'Preinfarction syndrome',
#   'Hypoxemia',
#   'Urinary tract infectious disease',
#   'Ulcer of lower extremity',
#   'Benzodiazepine sedative adverse reaction',
#   'Chronic diastolic heart failure',
#   'Acute respiratory failure',
#   'Uncomplicated umbilical hernia',
#   'Acute on chronic diastolic heart failure',
#   'Chronic pulmonary heart disease',
#   'Cellulitis and abscess of lower leg',
#   'Accident',
#   'Essential hypertension',
#   'Anoxic encephalopathy',
#   'Obesity',
#   'Feces contents abnormal',
#   'Arteriosclerosis of autologous vein coronary artery bypass graft',
#   'Acquired hypothyroidism',
#   'Congenital anomaly of cerebrovascular system',
#   'Seizure',
#   'Peripheral venous insufficiency',
#   'Coronary arteriosclerosis in native artery',
#   'Generalized convulsive epilepsy',
#   'High risk drug monitoring status',
#   'Acute renal failure syndrome',
#   'Chest pain',
#   'Atrial fibrillation',
#   'Diastolic heart failure',
#   'Gout',
#   'Glaucoma',
#   'Cardiac catheterization',
#   'Hyperlipidemia',
#   'Congestive heart failure',
#   'Altered mental status',
#   'Coronary atherosclerosis',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Aortic valve disorder'],
#  ['Gastrointestinal hemorrhage',
#   'Urinary tract infectious disease',
#   'Atrial fibrillation',
#   'Organic mental disorder',
#   'Congestive heart failure',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Osteoporosis',
#   'Acute on chronic diastolic heart failure',
#   'Urinary complication',
#   'Oliguria and anuria',
#   'Conjunctivitis'],
#  ['Acidosis',
#   'Cholelithiasis AND cholecystitis without obstruction',
#   'Epidermoid cyst of skin',
#   'Iatrogenic hypotension',
#   'Malignant tumor of colon',
#   'Opioid analgesic adverse reaction',
#   'Secondary malignant neoplasm of liver',
#   'Benign neoplasm of skin of face',
#   'Osteoporosis',
#   'Hemangioma of intra-abdominal structure',
#   'Obesity',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Diabetes mellitus without complication',
#   'Oliguria and anuria',
#   'Hypoxemia',
#   'Edema',
#   'Accident'],
#  ['Essential hypertension',
#   'Cardiac pacemaker in situ',
#   'Abdominal aortic aneurysm',
#   'Peritoneal adhesion',
#   'Vascular complication of medical care',
#   'Esophageal reflux finding',
#   'Primary cardiomyopathy',
#   'Chronic vascular insufficiency of intestine',
#   'Complication of procedure',
#   'Atherosclerosis of renal artery'],
#  ['Secondary malignant neoplasm of liver',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Incisional hernia',
#   'Disorder of biliary tract',
#   'Neoplasm of intra-abdominal lymph nodes'],
#  ['Essential hypertension',
#   'Acute renal failure syndrome',
#   'Severe sepsis',
#   'Secondary malignant neoplasm of liver',
#   'Acute respiratory failure',
#   'Shock',
#   'Sepsis',
#   'Perforation of intestine'],
#  ['Acute renal failure syndrome',
#   'Pneumonia due to Pseudomonas',
#   'Malignant tumor of colon',
#   'Peritoneal adhesion',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Sepsis due to Pseudomonas',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Diabetes mellitus without complication',
#   'Paroxysmal ventricular tachycardia'],
#  ['Gastrointestinal complication',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Pneumonia',
#   'Benign tumor of peritoneum and retroperitoneum',
#   'Paralytic ileus',
#   'Complication of surgical procedure'],
#  ['Acidosis',
#   'Secondary malignant neoplasm of liver',
#   'Delirium',
#   'Low blood pressure',
#   'Pneumonia',
#   'Neoplasm of intrathoracic lymph nodes',
#   'Blood coagulation disorder',
#   'Chronic obstructive lung disease',
#   'Secondary malignant neoplasm of pleura',
#   'Acute-on-chronic respiratory failure',
#   'Dependence on supplemental oxygen',
#   'Hypoxemia',
#   'Hematochezia',
#   'Urinary tract infectious disease',
#   'Chronic pulmonary heart disease',
#   'Pain control',
#   'Essential hypertension',
#   'Cardiac arrest',
#   'Anemia',
#   'Sepsis due to Streptococcus group D',
#   'Hypo-osmolality and or hyponatremia',
#   'Tricuspid valve disorder',
#   'Age related macular degeneration',
#   'Acute exacerbation of chronic obstructive bronchitis',
#   'High risk drug monitoring status',
#   'Atrial fibrillation',
#   'Diastolic heart failure',
#   'Congestive heart failure',
#   'Pleural effusion',
#   'Hypokalemia'],
#  ['Chronic cholecystitis',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Anemia',
#   'Secondary malignant neoplasm of liver'],
#  ['Acute renal failure syndrome',
#   'Anemia',
#   'Atrial fibrillation',
#   'Severe sepsis',
#   'Thrombocytopenic disorder',
#   'Neutropenic disorder',
#   'Acute respiratory failure',
#   'Cardiogenic shock',
#   'Septic shock',
#   'Sepsis'],
#  ['Essential hypertension',
#   'Acidosis',
#   'Diverticular disease of colon',
#   'Atrial fibrillation',
#   'Mitral valve disorder',
#   'Congestive heart failure',
#   'Tricuspid valve disorder',
#   'Intestinal obstruction'],
#  ['Acidosis',
#   'Secondary malignant neoplasm of liver',
#   'Neurological disorder with type 1 diabetes mellitus',
#   'Acute respiratory failure',
#   'Congestive heart failure',
#   'Diabetic polyneuropathy',
#   'Acute myocardial infarction'],
#  ['Delirium',
#   'Pancreatitis',
#   'Acute posthemorrhagic anemia',
#   'Pneumonitis due to inhalation of food or vomitus',
#   'Urinary complication',
#   'Diarrhea',
#   'Kidney disorder due to diabetes mellitus',
#   'Essential hypertension',
#   'Cardiac complication',
#   'Gastroduodenitis',
#   'Benign neoplasm of colon',
#   'Chest pain',
#   'Atrial fibrillation',
#   'Diastolic heart failure',
#   'Kidney disease',
#   'Accidental wound during procedure',
#   'Congestive heart failure',
#   'Hemorrhage AND/OR hematoma complicating procedure',
# ...
#   'Left bundle branch block',
#   'Inflammatory disorder of digestive tract',
#   'Esophageal reflux finding',
#   'Acute on chronic diastolic heart failure',
#   'Arthropathy of knee joint',
#   'Essential hypertension',
#   'Gastrointestinal hemorrhage',
#   'Anemia',
#   'Acquired hypothyroidism',
#   'Coronary arteriosclerosis in native artery',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Iatrogenic hypotension',
#   'Antiarrhythmic drug adverse reaction',
#   'Congestive heart failure',
#   'Anemia due to chronic blood loss'],
#  ['Acute renal failure syndrome',
#   'Gastrointestinal hemorrhage',
#   'Mechanical complication of device',
#   'Obstruction of bile duct',
#   'Severe sepsis',
#   'Hyperkalemia',
#   'Hyperlipidemia',
#   'Old myocardial infarction',
#   'Paroxysmal ventricular tachycardia',
#   'Sepsis due to Escherichia coli',
#   'Complication of procedure',
#   'Coronary arteriosclerosis in native artery',
#   'Tobacco dependence syndrome',
#   'Chronic total occlusion of coronary artery',
#   'Acute subendocardial infarction',
#   'Anemia due to chronic blood loss',
#   'Cholangitis'],
#  ['Secondary malignant neoplasm of liver',
#   'Peripheral vascular complication',
#   'Frank hematuria',
#   'Chronic obstructive lung disease',
#   'Acute systolic heart failure',
#   'Ascites',
#   'Intestinal obstruction',
#   'Urinary tract infectious disease',
#   'Cerebral infarction due to embolism of cerebral arteries',
#   'Primary malignant neoplasm of respiratory tract',
#   'Trauma and postoperative pulmonary insufficiency',
#   'Esophageal reflux finding',
#   'Complication of procedure',
#   'Drug withdrawal',
#   'Secondary malignant neoplasm of small intestine',
#   'Essential hypertension',
#   'Secondary malignant neoplasm of large intestine',
#   'Cardiac complication',
#   'Infarct of cerebrum due to iatrogenic cerebrovascular accident',
#   'Hypnotic or anxiolytic dependence, continuous',
#   'Disorder of artery',
#   'Perforation of intestine',
#   'Acute renal failure syndrome',
#   'Disorder of peritoneum',
#   'Iatrogenic hypotension',
#   'Acute myocardial infarction of anterior wall',
#   'Accidental wound during procedure',
#   'Congestive heart failure',
#   'Traumatic complication of procedure',
#   'Pleural effusion',
#   'Anemia due to chronic blood loss'],
#  ['Benign hypertensive renal disease with renal failure',
#   'Atrial fibrillation',
#   'Malignant ascites',
#   'Chronic kidney disease',
#   'Secondary malignant neoplasm of retroperitoneum and peritoneum',
#   'Pleural effusion',
#   'Intestinal obstruction',
#   'Hypovolemia',
#   'Diabetes mellitus without complication',
#   'Atrial flutter'],
#  ['Essential hypertension',
#   'Cardiac complication',
#   'Anemia',
#   'Atrial fibrillation',
#   'Gastrointestinal complication',
#   'Postoperative infection',
#   'Peritoneal adhesion',
#   'Purulent peritonitis',
#   'Coronary atherosclerosis',
#   'Esophageal reflux finding'],
#  ['Chronic lymphoid leukemia, disease',
#   'Benign hypertensive renal disease with renal failure',
#   'Cardiac complication',
#   'Atrial fibrillation',
#   'Gastrointestinal complication',
#   'Hematochezia',
#   'Primary malignant neoplasm of kidney',
#   'Chronic kidney disease stage 4',
#   'Chronic obstructive lung disease',
#   'Congestive heart failure',
#   'Pleural effusion',
#   'Acute on chronic diastolic heart failure',
#   'Neoplastic pleural effusion',
#   'Paralytic ileus',
#   'Sinus node dysfunction'],
#  ['Benign hypertensive renal disease with renal failure',
#   'Chest pain',
#   'Gout',
#   'Leukopenia',
#   'Delirium',
#   'Kidney disorder due to diabetes mellitus',
#   'Acquired hypothyroidism',
#   'Hyperlipidemia',
#   'Chronic kidney disease stage 4',
#   'Body mass index 30+ - obesity',
#   'Diabetic on insulin',
#   'Acute posthemorrhagic anemia',
#   'Acquired thrombocytopenia',
#   'Coronary arteriosclerosis in native artery',
#   'Acute subendocardial infarction'],
#  ['Essential hypertension',
#   'Perforation of intestine',
#   'Fistula of intestine',
#   'Anxiety disorder',
#   'Abscess of peritoneum',
#   'Acquired hypothyroidism',
#   'Depressive disorder',
#   'Hyperlipidemia',
#   'Chronic obstructive lung disease',
#   'Cholelithiasis without obstruction',
#   'Body mass index 40+ - severely obese',
#   'Disorder of kidney and/or ureter',
#   'Diabetes mellitus without complication',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Morbid obesity',
#   'Obstructive sleep apnea syndrome',
#   'Cellulitis and abscess of trunk'],
#  ['Diaphragmatic hernia',
#   'Secondary malignant neoplasm of liver',
#   'Anti-infectives adverse reaction',
#   'Anemia due to and following chemotherapy',
#   "Barrett's esophagus",
#   'Antineoplastic adverse reaction',
#   'Mitral and aortic incompetence',
#   'Stricture of esophagus',
#   'Acute posthemorrhagic anemia',
#   'Esophageal varices with bleeding, associated with another disorder',
#   'Acquired thrombocytopenia',
#   'Streptococcal infectious disease',
#   'Portal hypertension',
#   'Dermatitis due to drug AND/OR medicine taken internally',
#   'Diarrhea',
#   'Lower gastrointestinal hemorrhage',
#   'Bacteremia'],
#  ['Acute renal failure syndrome',
#   'Benign hypertensive renal disease with renal failure',
#   'Gout',
#   'Congenital hamartoma',
#   'Kidney disorder due to diabetes mellitus',
#   'Chronic diastolic heart failure',
#   'Congestive heart failure',
#   'Erythematous condition',
#   'Intestinal obstruction',
#   'Obesity',
#   'Peripheral venous insufficiency',
#   'Chronic pulmonary heart disease',
#   'Complication of surgical procedure',
#   'Chronic kidney disease stage 3',
#   'Obstructive sleep apnea syndrome',
#   'Aortic valve disorder'],
#  ['Essential hypertension',
#   'Anemia',
#   'Atrial fibrillation',
#   'Pneumonia',
#   'Pure hypercholesterolemia',
#   'Benign prostatic hypertrophy without outflow obstruction',
#   'Old myocardial infarction',
#   'Acute pancreatitis',
#   'Coronary arteriosclerosis in native artery',
#   'High risk drug monitoring status'],
#  ['Hematemesis',
#   'Hyperosmolality and or hypernatremia',
#   'Anemia in neoplastic disease',
#   'Disorder of phosphorus metabolism',
#   'Acute respiratory failure',
#   'Hyperkalemia',
#   'Wound seroma',
#   'Late effect of medical and surgical care complication',
#   'Essential hypertension',
#   'Cardiac complication',
#   'Severe sepsis',
#   'Alkalosis',
#   'Sepsis',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Postoperative infection',
#   'Peritoneal adhesion',
#   'Acute generalized peritonitis',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Septic shock'],
#  ['Acute renal failure syndrome',
#   'Severe sepsis',
#   'Atrial fibrillation',
#   'Urinary tract infectious disease',
#   'Hydronephrosis',
#   'Depressive disorder',
#   'Occlusion of ureter',
#   'Esophageal reflux finding',
#   'Sepsis due to Escherichia coli',
#   'Postoperative hypothyroidism',
#   'Sleep apnea',
#   'Pyelonephritis',
#   'Diabetes mellitus without complication',
#   'Septic shock',
#   'High risk drug monitoring status'],
#  ['Benign hypertensive renal disease with renal failure',
#   'Disorder of stoma',
#   'Iron deficiency anemia',
#   'Thrombocytopenic disorder',
#   'Depressive disorder',
#   'Hyperkalemia',
#   'Pressure ulcer stage 2',
#   'Acute on chronic diastolic heart failure',
#   'Acute cystitis',
#   'Cellulitis and abscess of trunk',
#   'Adrenal cortical hypofunction',
#   'Acquired hypothyroidism',
#   'Acute coronary syndrome',
#   'Pressure ulcer of buttock',
#   'Primary cardiomyopathy',
#   'Adverse reaction to hypnotic AND/OR sedative',
#   'Erysipelas',
#   'High risk drug monitoring status',
#   'Acute renal failure syndrome',
#   'Atrial fibrillation',
#   'Nutritional and metabolic cardiomyopathies',
#   'Hyperlipidemia',
#   'Chronic kidney disease stage 4',
#   'Congestive heart failure',
#   'Altered mental status',
#   'Osteoporosis',
#   'Bacterial infection due to Proteus mirabilis',
#   'Diabetes mellitus without complication',
#   'Paroxysmal ventricular tachycardia',
#   'Amyloidosis'],
#  ['Dementia',
#   'Old myocardial infarction',
#   'Joint pain',
#   'Hypoxemia',
#   'Hypervolemia',
#   'Alcohol abuse',
#   'Alcoholic cirrhosis',
#   'Low back pain',
#   'Late effect of medical and surgical care complication',
#   'Angina pectoris',
#   'Acute subendocardial infarction',
#   'Arthropathy of knee joint',
#   'Essential hypertension',
#   'Cardiac complication',
#   'Coronary arteriosclerosis in native artery',
#   'Acute on chronic systolic heart failure',
#   'Disorder of the peripheral nervous system',
#   'Arthropathy',
#   'Hyperlipidemia',
#   'Congestive heart failure',
#   'Pleural effusion',
#   'Heparin-induced thrombocytopenia'],
#  ['Acute pain',
#   'Urinary tract obstruction',
#   'Hyperosmolality and or hypernatremia',
#   'Acute posthemorrhagic anemia',
#   'Chronic pain',
#   'Intestinal obstruction',
#   'Pneumonitis due to inhalation of food or vomitus',
#   'Pressure ulcer',
#   'Pressure ulcer of lower back',
#   'Hematochezia',
#   'Urinary tract infectious disease',
#   'Pressure ulcer stage 2',
#   'Pressure ulcer of hip',
#   'Cerebral palsy',
#   'Blastomycosis',
#   'Esophageal reflux finding',
#   'Embolism and thrombosis of the vena cava',
#   'Cardiac arrest',
#   'Disorder of plasma protein metabolism',
#   'Hydronephrosis',
#   'Cachexia',
#   'Peripheral venous insufficiency',
#   'Physiological development failure',
#   'Leukocytosis',
#   'Hypoglycemia',
#   'Intellectual disability'],
#  ['Essential hypertension',
#   'Atrial fibrillation',
#   'Aortic valve disorder',
#   'Congenital insufficiency of aortic valve',
#   'Congenital anomaly of coronary artery',
#   'Coronary arteriosclerosis in native artery',
#   'Aortic valve stenosis'],
#  ['Antacid adverse reaction',
#   'Acidosis',
#   'Lung disease with systemic sclerosis',
#   'Complication of urinary catheter',
#   'Abnormal weight loss',
#   'Rheumatoid arthritis',
#   'Intestinal obstruction',
#   'Ascites',
#   'Systemic sclerosis',
#   'Gastrointestinal complication',
#   'Body mass index less than 20',
#   'Gangrenous disorder',
#   'Vascular complication of medical care',
#   'Complication of procedure',
#   "Raynaud's phenomenon",
#   'Late effect of medical and surgical care complication',
#   'Hypercoagulability state',
#   'Essential hypertension',
#   'Mycosis',
#   'Severe sepsis',
#   'Pancytopenia',
#   'Fistula of intestine',
#   'Acute deep venous thrombosis of upper extremity',
#   'Acquired thrombocytopenia',
#   'Antibacterial drug adverse reaction',
#   'Sepsis',
#   'Pneumonia due to methicillin resistant Staphylococcus aureus',
#   "Crohn's disease of small intestine",
#   'Pneumonia due to Escherichia coli',
#   'Postoperative infection',
#   'Accidental wound during procedure',
#   'Purulent peritonitis',
#   'Pleural effusion',
#   'Thrombosis of superficial vein of lower limb',
#   'Hemorrhage AND/OR hematoma complicating procedure'],
#  ['Diverticular disease of colon',
#   'Complication of procedure',
#   'Hemorrhage AND/OR hematoma complicating procedure',
#   'Idiopathic thrombocytopenic purpura',
#   'Lower gastrointestinal hemorrhage'],
#  ['Essential hypertension',
#   'Hematochezia',
#   'Anemia',
#   'Insomnia',
#   'Hyperlipidemia',
#   'Hyperosmolality and or hypernatremia',
#   'Diabetes mellitus without complication',
#   'Lower gastrointestinal hemorrhage'],
#  ['Complication of urinary catheter',
#   'Cystic disease of kidney',
#   'Primary malignant neoplasm of large intestine',
#   'Cardiogenic shock',
#   'Chronic obstructive lung disease',
#   'Colitis',
#   'Retention of urine',
#   'Acute posthemorrhagic anemia',
#   'Intestinal obstruction',
#   'Anemia due to chronic blood loss',
#   'Osteoarthritis',
#   'Anemia in neoplastic disease',
#   'Urinary tract infectious disease',
#   'Chronic diastolic heart failure',
#   'Benign prostatic hypertrophy without outflow obstruction',
#   'Septic shock',
#   'Osteitis deformans without bone tumor',
#   'Acute on chronic diastolic heart failure',
#   'Chronic kidney disease stage 3',
#   'Gastrointestinal hemorrhage',
#   'Severe sepsis',
#   'Pulmonary arterial hypertension',
#   'Hydronephrosis',
#   'Pulmonary embolism with pulmonary infarction',
#   'Acquired hypothyroidism',
#   'Cardiac pacemaker in situ',
#   'Chronic kidney disease',
#   'Sepsis due to Escherichia coli',
#   'Disorder of kidney and/or ureter',
#   'Sepsis',
#   'Anorectal abscess',
#   'Sinus node dysfunction',
#   'Acute renal failure syndrome',
#   'Benign neoplasm of colon',
#   'Atrial fibrillation',
#   'Dehydration',
#   'Congestive heart failure',
#   'Pleural effusion',
#   'Dyspnea',
#   'Osteoporosis',
#   'Clostridium difficile infection',
#   'Bacterial pneumonia'],
#  ['Urinary tract infectious disease',
#   'Bipolar disorder',
#   'Gastrointestinal complication',
#   'Iatrogenic hypotension',
#   'Acute respiratory failure',
#   'Hyperlipidemia',
#   'Benign prostatic hypertrophy with outflow obstruction',
#   'Intestinal volvulus',
#   'Myoneural disorder',
#   'Acquired hypertrophic pyloric stenosis',
#   'Retention of urine',
#   'Schizophrenia',
#   'Paralytic ileus',
#   'Late effect of medical and surgical care complication',
#   'Disorder of upper gastrointestinal tract',
#   'Secondary malignant neoplasm of small intestine'],
#  ['Acute renal failure syndrome',
#   'Atherosclerosis of native arteries of the extremities',
#   'Perforation of intestine',
#   'Delirium',
#   'Pneumonia',
#   'Hyperlipidemia',
#   'Paralytic syndrome of nondominant side as late effect of stroke',
#   'Acute deep venous thrombosis of upper extremity',
#   'Gastrointestinal perforation',
#   'Old myocardial infarction',
#   'Diabetic on insulin',
#   'Coronary atherosclerosis',
#   'Ascites',
#   'Neoplasm of intra-abdominal lymph nodes',
#   'Nonproliferative diabetic retinopathy',
#   'Type 1 diabetes mellitus uncontrolled',
#   'Bacteremia'],
#  ['Atrial fibrillation',
#   'Pure hypercholesterolemia',
#   'Subdural hemorrhage following injury without open intracranial wound AND with no loss of consciousness',
#   'Benign prostatic hypertrophy without outflow obstruction',
#   'Organic mental disorder',
#   'Subdural hematoma',
#   'Fall on same level from slipping, tripping or stumbling',
#   'High risk drug monitoring status'],
#  ['Essential hypertension', 'Osteoporosis', 'Malignant tumor of colon'],
#  ['Essential hypertension',
#   'Dehydration',
#   'Secondary malignant neoplasm of liver',
#   'Pulmonary embolism with pulmonary infarction',
#   'Secondary malignant neoplasm of adrenal gland',
#   'Inflammatory disorder of digestive tract',
#   'Antineoplastic adverse reaction',
#   'Esophageal reflux finding',
#   'Hypokalemia',
#   'Hypercoagulability state'],
#  ['Not for resuscitation',
#   'Atrial fibrillation',
#   'Cerebral edema',
#   'Hemiplegia of dominant side',
#   'Infarct of cerebrum due to iatrogenic cerebrovascular accident',
#   'Chronic obstructive lung disease',
#   'Stroke',
#   'Esophageal reflux finding',
#   'High risk drug monitoring status'],
#  ['Cerebral edema',
#   'Frank hematuria',
#   'Acute systolic heart failure',
#   'Anticoagulant adverse reaction',
#   'Esophagitis',
#   'Intestinal obstruction',
#   'Acute deep vein thrombosis of lower limb',
#   'Urinary tract infectious disease',
#   'Acute pulmonary edema',
#   'Acute respiratory failure',
#   'Benign essential hypertension',
#   'Esophageal reflux finding',
#   'Chronic pulmonary heart disease',
#   'Cerebrovascular disease',
#   'Acute subendocardial infarction',
#   'Essential hypertension',
#   'Gastrointestinal hemorrhage',
#   'Severe sepsis',
#   'Pulmonary embolism with pulmonary infarction',
#   'Coronary arteriosclerosis in native artery',
#   'Complication of surgical procedure',
#   'Obstructive hydrocephalus',
#   'Sepsis',
#   'Atrial fibrillation',
#   'Postoperative infection',
#   'Compression of brain',
#   'Abdominal aortic aneurysm',
#   'Accidental wound during procedure',
#   'Congestive heart failure',
#   'Pleural effusion'],
#  ['Iatrogenic hypotension',
#   'Low blood pressure',
#   'Colitis',
#   'Hemorrhage of rectum and anus'],
#  ['Anemia in chronic kidney disease',
#   'Acute renal failure syndrome',
#   'Benign hypertensive renal disease with renal failure',
#   'Subdural hemorrhage following injury without open intracranial wound AND with no loss of consciousness',
#   'Hyperlipidemia',
#   'Right bundle branch block AND left anterior fascicular block',
#   'Chronic kidney disease',
#   'Subdural hematoma',
#   'Diabetes mellitus without complication',
#   'Fall on same level from slipping, tripping or stumbling',
#   'Secondary malignant neoplasm of lung']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(comorb_list).transform(comorb_list)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head(25)
# Out:
#     Abdominal aortic aneurysm  Abdominal compartment syndrome  Abdominal pain  \
# 0                       False                           False           False
# 1                       False                           False           False
# 2                       False                           False           False
# 3                       False                           False           False
# 4                       False                           False           False
# 5                       False                           False           False
# 6                       False                           False           False
# 7                       False                           False           False
# 8                       False                           False           False
# 9                       False                           False           False
# 10                      False                           False            True
# 11                      False                           False           False
# 12                      False                           False           False
# 13                      False                           False           False
# 14                      False                           False           False
# 15                      False                           False           False
# 16                      False                           False           False
# 17                      False                           False           False
# 18                      False                           False           False
# 19                      False                           False           False
# 20                      False                           False            True
# 21                      False                           False           False
# 22                      False                           False           False
# 23                      False                           False            True
# 24                      False                           False           False
#
#     Abnormal body temperature  Abnormal breathing  Abnormal gait  \
# 0                       False               False          False
# 1                       False               False          False
# 2                       False               False          False
# 3                       False               False          False
# 4                       False               False          False
# 5                       False               False          False
# 6                       False               False          False
# 7                       False               False          False
# 8                       False               False          False
# 9                       False               False          False
# 10                      False               False          False
# 11                      False               False          False
# 12                      False               False          False
# 13                      False               False          False
# 14                      False               False          False
# 15                      False               False          False
# 16                      False               False          False
# 17                      False               False          False
# 18                      False               False          False
# 19                      False               False          False
# 20                      False               False          False
# 21                      False               False          False
# 22                      False               False          False
# 23                      False               False          False
# 24                      False               False          False
#
#     Abnormal patient reaction  Abnormal uterine bleeding  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# 5                       False                      False
# 6                       False                      False
# 7                       False                      False
# 8                       False                      False
# 9                       False                      False
# 10                      False                      False
# 11                      False                      False
# 12                      False                      False
# 13                      False                      False
# 14                      False                      False
# 15                      False                      False
# 16                      False                      False
# 17                      False                      False
# 18                      False                      False
# 19                      False                      False
# 20                      False                      False
# 21                      False                      False
# 22                      False                      False
# 23                      False                      False
# 24                      False                      False
#
#     Abnormal weight loss  Abscess of intestine  ...  \
# 0                  False                 False  ...
# 1                  False                 False  ...
# 2                  False                 False  ...
# 3                  False                 False  ...
# 4                  False                 False  ...
# 5                  False                 False  ...
# 6                  False                 False  ...
# 7                  False                 False  ...
# 8                  False                 False  ...
# 9                  False                 False  ...
# 10                 False                 False  ...
# 11                 False                 False  ...
# 12                 False                 False  ...
# 13                 False                 False  ...
# 14                 False                 False  ...
# 15                 False                 False  ...
# 16                 False                 False  ...
# 17                 False                 False  ...
# 18                 False                 False  ...
# 19                 False                 False  ...
# 20                 False                 False  ...
# 21                 False                 False  ...
# 22                 False                 False  ...
# 23                 False                 False  ...
# 24                 False                 False  ...
#
#     Vascular insufficiency of intestine  Venous thrombosis  Venous varices  \
# 0                                 False              False           False
# 1                                 False              False           False
# 2                                 False              False           False
# 3                                 False              False           False
# 4                                 False              False           False
# 5                                 False              False           False
# 6                                 False              False           False
# 7                                 False              False           False
# 8                                 False              False           False
# 9                                 False              False           False
# 10                                False              False           False
# 11                                False              False           False
# 12                                False              False           False
# 13                                False              False           False
# 14                                False              False           False
# 15                                False              False           False
# 16                                False              False           False
# 17                                False              False           False
# 18                                False              False           False
# 19                                False              False           False
# 20                                False              False           False
# 21                                False              False           False
# 22                                False              False           False
# 23                                False              False           False
# 24                                False              False           False
#
#     Ventricular fibrillation  Viral hepatitis B without hepatic coma  \
# 0                      False                                   False
# 1                      False                                   False
# 2                      False                                   False
# 3                      False                                   False
# 4                      False                                   False
# 5                      False                                   False
# 6                      False                                   False
# 7                      False                                   False
# 8                      False                                   False
# 9                      False                                   False
# 10                     False                                   False
# 11                     False                                   False
# 12                     False                                   False
# 13                     False                                   False
# 14                     False                                   False
# 15                     False                                   False
# 16                     False                                   False
# 17                     False                                   False
# 18                     False                                   False
# 19                     False                                   False
# 20                     False                                   False
# 21                     False                                   False
# 22                     False                                   False
# 23                     False                                   False
# 24                     False                                   False
#
#     Vitamin B deficiency  Vocal cord paralysis  Vomiting  Wound dehiscence  \
# 0                  False                 False     False             False
# 1                  False                 False     False             False
# 2                  False                 False     False             False
# 3                  False                 False     False             False
# 4                  False                 False     False             False
# 5                  False                 False     False             False
# 6                  False                 False     False             False
# 7                  False                 False     False             False
# 8                  False                 False     False             False
# 9                  False                 False     False             False
# 10                 False                 False     False             False
# 11                 False                 False     False             False
# 12                 False                 False     False             False
# 13                 False                 False     False             False
# 14                 False                 False     False             False
# 15                 False                 False     False             False
# 16                 False                 False     False             False
# 17                 False                 False     False             False
# 18                 False                 False     False             False
# 19                 False                 False     False             False
# 20                 False                 False     False             False
# 21                 False                 False     False             False
# 22                 False                 False     False             False
# 23                 False                 False     False             False
# 24                 False                 False     False             False
#
#     Wound seroma
# 0           True
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
#
# [25 rows x 752 columns]

# %%
# %%time
from mlxtend.frequent_patterns import apriori
support = 0.01
frequent_itemsets = apriori(df, min_support=support, use_colnames=True)
print(f"Using a support of {support}, found {len(frequent_itemsets)} frequent itemsets")
frequent_itemsets.head(25)
# Out:
# Using a support of 0.01, found 17736 frequent itemsets
# Wall time: 1.93 s
#      support                                           itemsets
# 0   0.023474                        (Abdominal aortic aneurysm)
# 1   0.037559                                   (Abdominal pain)
# 2   0.018779                        (Abnormal patient reaction)
# 3   0.018779                             (Abnormal weight loss)
# 4   0.014085                             (Abscess of intestine)
# 5   0.028169                            (Abscess of peritoneum)
# 6   0.051643                                         (Accident)
# 7   0.065728                (Accidental wound during procedure)
# 8   0.169014                                         (Acidosis)
# 9   0.018779           (Acquired coagulation factor deficiency)
# 10  0.112676                          (Acquired hypothyroidism)
# 11  0.014085                        (Acquired thrombocytopenia)
# 12  0.014085         (Acute deep vein thrombosis of lower limb)
# 13  0.018779                    (Acute diastolic heart failure)
# 14  0.032864           (Acute disease of cardiovascular system)
# 15  0.028169  (Acute exacerbation of chronic obstructive bro...
# 16  0.014085                      (Acute myocardial infarction)
# 17  0.018779     (Acute myocardial infarction of anterior wall)
# 18  0.014085  (Acute on chronic combined systolic and diasto...
# 19  0.075117         (Acute on chronic diastolic heart failure)
# 20  0.028169          (Acute on chronic systolic heart failure)
# 21  0.014085                               (Acute pancreatitis)
# 22  0.215962                     (Acute posthemorrhagic anemia)
# 23  0.018779                            (Acute pulmonary edema)
# 24  0.361502                     (Acute renal failure syndrome)

# %%
frequent_itemsets['count'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets.head(25)
# Out:
#      support                                           itemsets  count
# 0   0.023474                        (Abdominal aortic aneurysm)      1
# 1   0.037559                                   (Abdominal pain)      1
# 2   0.018779                        (Abnormal patient reaction)      1
# 3   0.018779                             (Abnormal weight loss)      1
# 4   0.014085                             (Abscess of intestine)      1
# 5   0.028169                            (Abscess of peritoneum)      1
# 6   0.051643                                         (Accident)      1
# 7   0.065728                (Accidental wound during procedure)      1
# 8   0.169014                                         (Acidosis)      1
# 9   0.018779           (Acquired coagulation factor deficiency)      1
# 10  0.112676                          (Acquired hypothyroidism)      1
# 11  0.014085                        (Acquired thrombocytopenia)      1
# 12  0.014085         (Acute deep vein thrombosis of lower limb)      1
# 13  0.018779                    (Acute diastolic heart failure)      1
# 14  0.032864           (Acute disease of cardiovascular system)      1
# 15  0.028169  (Acute exacerbation of chronic obstructive bro...      1
# 16  0.014085                      (Acute myocardial infarction)      1
# 17  0.018779     (Acute myocardial infarction of anterior wall)      1
# 18  0.014085  (Acute on chronic combined systolic and diasto...      1
# 19  0.075117         (Acute on chronic diastolic heart failure)      1
# 20  0.028169          (Acute on chronic systolic heart failure)      1
# 21  0.014085                               (Acute pancreatitis)      1
# 22  0.215962                     (Acute posthemorrhagic anemia)      1
# 23  0.018779                            (Acute pulmonary edema)      1
# 24  0.361502                     (Acute renal failure syndrome)      1

# %%
fi = frequent_itemsets.sort_values(by = ['support'], ascending = False)
print(f"Highest support is {fi.iloc[0]['support']} with a count of {fi.iloc[0]['count']}")
print(f"Lowest support is {fi.iloc[-1]['support']} with a count of {fi.iloc[-1]['count']}")
fi.head(25)
# Out:
# Highest support is 0.5023474178403756 with a count of 1
# Lowest support is 0.014084507042253521 with a count of 8
#        support                                           itemsets  count
# 131   0.502347                           (Essential hypertension)      1
# 54    0.408451                              (Atrial fibrillation)      1
# 95    0.361502                         (Congestive heart failure)      1
# 24    0.361502                     (Acute renal failure syndrome)      1
# 98    0.239437       (Coronary arteriosclerosis in native artery)      1
# 1222  0.239437      (Essential hypertension, Atrial fibrillation)      2
# 106   0.234742           (Diabetes mellitus without complication)      1
# 1203  0.230047    (Atrial fibrillation, Congestive heart failure)      2
# 22    0.215962                     (Acute posthemorrhagic anemia)      1
# 170   0.211268                           (Intestinal obstruction)      1
# 1712  0.211268  (Essential hypertension, Congestive heart fail...      2
# 152   0.206573                                   (Hyperlipidemia)      1
# 186   0.192488          (Neoplasm of intra-abdominal lymph nodes)      1
# 643   0.192488  (Acute renal failure syndrome, Atrial fibrilla...      2
# 682   0.192488  (Essential hypertension, Acute renal failure s...      2
# 238   0.187793            (Secondary malignant neoplasm of liver)      1
# 246   0.183099                                           (Sepsis)      1
# 271   0.173709                 (Urinary tract infectious disease)      1
# 665   0.173709  (Acute renal failure syndrome, Congestive hear...      2
# 25    0.173709                        (Acute respiratory failure)      1
# 251   0.169014                                    (Severe sepsis)      1
# 8     0.169014                                         (Acidosis)      1
# 130   0.169014                        (Esophageal reflux finding)      1
# 1808  0.159624  (Essential hypertension, Coronary arterioscler...      2
# 139   0.159624                      (Gastrointestinal hemorrhage)      1

# %%
fige2 = fi[fi['count'] >= 2]
fige2.head(25)
# Out:
#        support                                           itemsets  count
# 1222  0.239437      (Essential hypertension, Atrial fibrillation)      2
# 1203  0.230047    (Atrial fibrillation, Congestive heart failure)      2
# 1712  0.211268  (Essential hypertension, Congestive heart fail...      2
# 643   0.192488  (Acute renal failure syndrome, Atrial fibrilla...      2
# 682   0.192488  (Essential hypertension, Acute renal failure s...      2
# 665   0.173709  (Acute renal failure syndrome, Congestive hear...      2
# 1808  0.159624  (Essential hypertension, Coronary arterioscler...      2
# 1697  0.140845  (Congestive heart failure, Coronary arterioscl...      2
# 1918  0.140845  (Essential hypertension, Diabetes mellitus wit...      2
# 2068  0.136150           (Essential hypertension, Hyperlipidemia)      2
# 5921  0.136150  (Essential hypertension, Atrial fibrillation, ...      3
# 759   0.131455      (Acute renal failure syndrome, Severe sepsis)      2
# 2683  0.126761                            (Severe sepsis, Sepsis)      2
# 1702  0.122066  (Congestive heart failure, Diabetes mellitus w...      2
# 4027  0.122066  (Essential hypertension, Acute renal failure s...      3
# 755   0.122066             (Acute renal failure syndrome, Sepsis)      2
# 2139  0.117371            (Essential hypertension, Severe sepsis)      2
# 1205  0.117371  (Atrial fibrillation, Coronary arteriosclerosi...      2
# 4016  0.112676  (Acute renal failure syndrome, Atrial fibrilla...      3
# 667   0.112676  (Acute renal failure syndrome, Coronary arteri...      2
# 2082  0.112676   (Essential hypertension, Intestinal obstruction)      2
# 1210  0.107981  (Atrial fibrillation, Diabetes mellitus withou...      2
# 566   0.107981  (Essential hypertension, Acute posthemorrhagic...      2
# 2014  0.107981  (Essential hypertension, Esophageal reflux fin...      2
# 2696  0.103286                      (Severe sepsis, Septic shock)      2
